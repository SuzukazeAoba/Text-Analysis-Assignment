# %% [markdown]
# # Import package

# %%
import nltk
import numpy as np
import pandas as pd
import re
from nltk.corpus import wordnet as wn

# %%
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /Users/admin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/admin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/admin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Load data set

# %%
documents = pd.read_csv("./nlp_country.csv")
documents
# Out:
#              Name                                           Abstract
# 0           Japan  Japan is an island country in East Asia. Locat...
# 1   United States  The United States of America (USA), commonly k...
# 2         England  England is a country that is part of the Unite...
# 3           China  China, officially the People's Republic of Chi...
# 4           India  India, also known as the Republic of India,[19...
# 5           Korea  Korea is a region in East Asia.[3] Since 1948 ...
# 6         Germany  Germany, officially the Federal Republic of Ge...
# 7          Russia  Russia, or the Russian Federation[12], is a tr...
# 8          France  France, officially the French Republic, is a c...
# 9           Italy  Italy, officially the Italian Republic,[10][11...
# 10         Brazil  Brazil officially the Federative Republic of B...
# 11         Canada  Canada is a country in the northern part of No...
# 12          Spain  Spain, officially the Kingdom of Spain[11][a][...
# 13      Australia  Australia, officially the Commonwealth of Aust...
# 14      Indonesia  Indonesia, officially the Republic of Indonesi...
# 15         Mexico  Mexico, officially the United Mexican States (...

# %%
text_data = documents["Abstract"].values
text_data
# Out:
# array(['Japan is an island country in East Asia. Located in the Pacific Ocean, it lies off the eastern coast of the Asian continent and stretches from the Sea of Okhotsk in the north to the East China Sea and the Philippine Sea in the south. The kanji that make up Japan\'s name mean \'sun origin\', and it is often called the "Land of the Rising Sun". Japan is a stratovolcanic archipelago consisting of about 6,852 islands. The four largest are Honshu, Hokkaido, Kyushu, and Shikoku, which make up about ninety-seven percent of Japan\'s land area and often are referred to as home islands. The country is divided into 47 prefectures in eight regions, with Hokkaido being the northernmost prefecture and Okinawa being the southernmost one. Japan is the 2nd most populous island country. The population of 127 million is the world\'s eleventh largest, of which 98.5% are ethnic Japanese. 90.7% of people live in cities, while 9.3% live in the countryside.[16] About 13.8 million people live in Tokyo,[17] the capital of Japan. The Greater Tokyo Area is the most populous metropolitan area in the world with over 38 million people.[18] Archaeological research indicates that Japan was inhabited as early as the Upper Paleolithic period. The first written mention of Japan is in Chinese history texts from the 1st century AD. Influence from other regions, mainly China, followed by periods of isolation, particularly from Western Europe, has characterized Japan\'s history. From the 12th century until 1868, Japan was ruled by successive feudal military shōguns who ruled in the name of the Emperor. Japan entered into a long period of isolation in the early 17th century, which was ended in 1853 when a United States fleet pressured Japan to open to the West. After nearly two decades of internal conflict and insurrection, the Imperial Court regained its political power in 1868 through the help of several clans from Chōshū and Satsuma – and the Empire of Japan was established. In the late 19th and early 20th centuries, victories in the First Sino-Japanese War, the Russo-Japanese War and World War I allowed Japan to expand its empire during a period of increasing militarism. The Second Sino-Japanese War of 1937 expanded into part of World War II in 1941, which came to an end in 1945 following the Japanese surrender. Since adopting its revised constitution on May 3, 1947, during the occupation led by SCAP, the sovereign state of Japan has maintained a unitary parliamentary constitutional monarchy with an Emperor and an elected legislature called the National Diet. Japan is a member of the ASEAN Plus mechanism, UN, the OECD, the G7, the G8, and the G20, and is considered a great power.[19][20][21] Its economy is the world\'
erful base in Mexico-Tenochtitlan (part of Mexico City), which was administered as the viceroyalty of New Spain. Three centuries later, the territory became a nation state following its recognition in 1821 after the Mexican War of Independence. The post-independence period was tumultuous, characterized by economic inequality and many contrasting political changes. The Mexican–American War (1846–1848) led to a territorial cession of the extant northern territories to the United States. The Pastry War, the Franco-Mexican War, a civil war, two empires, and the Porfiriato occurred in the 19th century. The Porfiriato ended with the Mexican Revolution in 1910, which culminated in the promulgation of the 1917 Constitution and the emergence of an authoritarian one-party state,[16][17][18][19] once widely described as the "perfect dictatorship,"[20][21][22] that ruled for much of the 20th Century until electoral reforms and opposition victories led to Mexico\'s democratic transition in the 1990s.[23][24][25][26] Mexico has the 15th largest nominal GDP and the 11th largest by purchasing power parity. The Mexican economy is strongly linked to those of its 1994 North American Free Trade Agreement (NAFTA) partners, especially the United States.[27][28] In 1994, Mexico became the first Latin American member of the Organisation for Economic Co-operation and Development (OECD). It is classified as an upper-middle income country by the World Bank[29] and a newly industrialized country by several analysts.[30][31][32][33] The country is considered both a regional power and a middle power,[34][35][36][37] and is often identified as an emerging global power.[38] Due to its rich culture and history, Mexico ranks first in the Americas and seventh in the world for number of UNESCO World Heritage Sites.[39][40][41] Mexico is an ecologically megadiverse country, ranking fourth in the world for its biodiversity. Mexico receives a huge number of tourists every year: in 2018, it was the sixth most-visited country in the world, with 39 million international arrivals.[42] Mexico is a member of the United Nations (UN), the World Trade Organization (WTO), the G8+5, the G20, the Uniting for Consensus group of the UN, and the Pacific Alliance trade bloc.'],
#       dtype=object)

# %% [markdown]
# # Preprocessing

# %%
en_stop = nltk.corpus.stopwords.words('english')

# %%
def preprocessing_text(text):
    def cleaning_text(text):
        pattern1 = '@|%'
        text = re.sub(pattern1, '', text)    
        pattern2 = '\[[0-9 ]*\]'
        text = re.sub(pattern2, '', text)    
        pattern3 = '\([a-z ]*\)'
        text = re.sub(pattern3, '', text)    
        pattern4 = '[0-9]'
        text = re.sub(pattern4, '', text)
        return text
  
    def tokenize_text(text):
        text = re.sub('[.,]', '', text)
        return text.split()

    def lemmatize_word(word):
        word=word.lower()
    
        lemma = wn.morphy(word)
        if lemma is None:
            return word
        else:
            return lemma
    
    def remove_stopwords(word, stopwordset):
        if word in stopwordset:
            return None
        else:
            return word
            
    text = cleaning_text(text)
    tokens = tokenize_text(text)
    tokens = [lemmatize_word(word) for word in tokens]
    tokens = [remove_stopwords(word, en_stop) for word in tokens]
    tokens = [word for word in tokens if word is not None]
    return tokens

# %%
pp_text_data = [preprocessing_text(text) for text in text_data]
pp_text_data
# Out:
# [['japan',
#   'island',
#   'country',
#   'east',
#   'asia',
#   'locate',
#   'pacific',
#   'ocean',
#   'lie',
#   'eastern',
#   'coast',
#   'asian',
#   'continent',
#   'stretch',
#   'sea',
#   'okhotsk',
#   'north',
#   'east',
#   'china',
#   'sea',
#   'philippine',
#   'sea',
#   'south',
#   'kanji',
#   'make',
#   "japan's",
#   'name',
#   'mean',
#   "'sun",
#   "origin'",
#   'often',
#   'call',
#   '"land',
#   'rising',
#   'sun"',
#   'japan',
#   'stratovolcanic',
#   'archipelago',
#   'consist',
#   'island',
#   'four',
#   'large',
#   'honshu',
#   'hokkaido',
#   'kyushu',
#   'shikoku',
#   'make',
#   'ninety-seven',
#   'percent',
#   "japan's",
#   'land',
#   'area',
#   'often',
#   'refer',
#   'home',
#   'island',
#   'country',
#   'divide',
#   'prefecture',
#   'eight',
#   'region',
#   'hokkaido',
#   'northernmost',
#   'prefecture',
#   'okinawa',
#   'southernmost',
#   'one',
#   'japan',
#   'nd',
#   'populous',
#   'island',
#   'country',
#   'population',
#   'million',
#   "world's",
#   'eleventh',
#   'large',
#   'ethnic',
#   'japanese',
#   'people',
#   'live',
#   'city',
#   'live',
#   'countryside',
#   'million',
#   'people',
#   'live',
#   'tokyo',
#   'capital',
#   'japan',
#   'greater',
#   'tokyo',
#   'area',
#   'populous',
#   'metropolitan',
#   'area',
#   'world',
#   'million',
#   'people',
#   'archaeological',
#   'research',
#   'indicate',
#   'japan',
#   'wa',
#   'inhabit',
#   'early',
#   'upper',
#   'paleolithic',
#   'period',
#   'first',
#   'write',
#   'mention',
#   'japan',
#   'chinese',
#   'history',
#   'text',
#   'st',
#   'century',
#   'ad',
#   'influence',
#   'region',
#   'mainly',
#   'china',
#   'follow',
#   'period',
#   'isolation',
#   'particularly',
#   'western',
#   'europe',
#   'ha',
#   'characterize',
#   "japan's",
#   'history',
#   'th',
#   'century',
#   'japan',
#   'wa',
#   'rule',
#   'successive',
#   'feudal',
#   'military',
#   'shōguns',
#   'rule',
#   'name',
#   'emperor',
#   'japan',
#   'enter',
#   'long',
#   'period',
#   'isolation',
#   'early',
#   'th',
#   'century',
#   'wa',
#   'end',
#   'unite',
#   'state',
#   'fleet',
#   'pressure',
#   'japan',
#   'open',
#   'west',
#   'nearly',
#   'two',
#   'decade',
#   'internal',
#   'conflict',
#   'insurrection',
#   'imperial',
#   'court',
#   'regain',
#   'political',
#   'power',
#   'help',
#   'several',
#   'clan',
#   'chōshū',
#   'satsuma',
#   '–',
#   'empire',
#   'japan',
#   'wa',
#   'establish',
#   'late',
#   'th',
#   'early',
#   'th',
#   'century',
#   'victory',
#   'first',
#   'sino-japanese',
#   'war',
#   'russo-japanese',
#   'war',
#   'world',
#   'war',
#   'allow',
#   'japan',
#   'expand',
#   'empire',
#   'period',
#   'increase',
#   'militarism',
#   'second',
#   'sino-japanese',
#   'war',
#   'expand',
#   'part',
#   'world',
#   'war',
#   'ii',
#   'come',
#   'end',
#   'following',
#   'japanese',
#   'surrender',
#   'since',
#   'adopt',
#   'revise',
#   'constitution',
#   'may',
#   'occupation',
#   'led',
#   'scap',
#   'sovereign',
#   'state',
#   'japan',
#   'ha',
#   'maintain',
#   'unitary',
#   'parliamentary',
#   'constitutional',
#   'monarchy',
#   'emperor',
#   'elect',
#   'legislature',
#   'call',
#   'national',
#   'diet',
#   'japan',
#   'member',
#   'asean',
#   'plus',
#   'mechanism',
#   'un',
#   'oecd',
#   'g',
#   'g',
#   'g',
#   'consider',
#   'great',
#   'power',
#   'economy',
#   "world's",
#   'third-largest',
#   'nominal',
#   'gdp',
#   'fourth-largest',
#   'purchasing',
#   'power',
#   'parity',
#   'also',
#   "world's",
#   'fourth-largest',
#   'exporter',
#   'fourth-largest',
#   'importer',
#   'japan',
#   'benefit',
#   'highly',
#   'skilled',
#   'educate',
#   'workforce;',
#   'ha',
#   'among',
#   "world's",
#   'large',
#   'proportion',
#   'citizen',
#   'holding',
#   'tertiary',
#   'education',
#   'degree',
#   'although',
#   'ha',
#   'officially',
#   'renounce',
#   'right',
#   'declare',
#   'war',
#   'japan',
#   'maintain',
#   'modern',
#   'military',
#   "world's",
#   'eighth-largest',
#   'military',
#   'budget',
#   'use',
#   'self-defense',
#   'peacekeeping',
#   'roles;',
#   'rank',
#   "world's",
#   'fourth',
#   'most-powerful',
#   'military',
#   'japan',
#   'highly',
#   'develop',
#   'country',
#   'high',
#   'standard',
#   'living',
#   'human',
#   'development',
#   'index',
#   'population',
#   'enjoy',
#   'high',
#   'life',
#   'expectancy',
#   'third',
#   'lowest',
#   'infant',
#   'mortality',
#   'rate',
#   'world',
#   'experience',
#   'issue',
#   'due',
#   'aging',
#   'population',
#   'low',
#   'birthrate',
#   'japan',
#   'renowned',
#   'historical',
#   'extensive',
#   'cinema',
#   'influential',
#   'music',
#   'industry',
#   'anime',
#   'video',
#   'gaming',
#   'rich',
#   'cuisine',
#   'major',
#   'contribution',
#   'science',
#   'modern',
#   'technology'],
#  ['unite',
#   'state',
#   'america',
#   '(usa)',
#   'commonly',
#   'know',
#   'unite',
#   'state',
#   '(us',
#   'us)',
#   'america',
#   'country',
#   'comprise',
#   'state',
#   'federal',
#   'district',
#   'five',
#   'major',
#   'self-governing',
#   'territory',
#   'various',
#   'possessions[h]',
#   'million',
#   'square',
#   'mile',
#   '(',
#   'million',
#   'km)',
#   'unite',
#   'state',
#   "world's",
#   'third',
#   'fourth',
#   'large',
#   'country',
#   'total',
#   'area[d]',
#   'slightly',
#   'smaller',
#   'entire',
#   'continent',
#   "europe's",
#   'million',
#   'square',
#   'mile',
#   '(',
#   'million',
#   'km)',
#   'population',
#   'million',
#   'people',
#   'us',
#   'third',
#   'populous',
#   'country',
#   'capital',
#   'washington',
#   'dc',
#   'populous',
#   'city',
#   'new',
#   'york',
#   'city',
#   'forty-eight',
#   'state',
#   "capital's",
#   'federal',
#   'district',
#   'contiguous',
#   'north',
#   'america',
#   'canada',
#   'mexico',
#   'state',
#   'alaska',
#   'northwest',
#   'corner',
#   'north',
#   'america',
#   'border',
#   'canada',
#   'east',
#   'across',
#   'bering',
#   'strait',
#   'russia',
#   'west',
#   'state',
#   'hawaii',
#   'archipelago',
#   'mid-pacific',
#   'ocean',
#   'us',
#   'territory',
#   'scatter',
#   'pacific',
#   'ocean',
#   'caribbean',
#   'sea',
#   'stretching',
#   'across',
#   'nine',
#   'official',
#   'time',
#   'zone',
#   'extremely',
#   'diverse',
#   'geography',
#   'climate',
#   'wildlife',
#   'unite',
#   'state',
#   'make',
#   'one',
#   "world's",
#   'megadiverse',
#   'country',
#   'paleo-indian',
#   'migrate',
#   'siberia',
#   'north',
#   'american',
#   'mainland',
#   'least',
#   'years',
#   'ago',
#   'european',
#   'colonization',
#   'begin',
#   'th',
#   'century',
#   'unite',
#   'state',
#   'emerge',
#   'thirteen',
#   'british',
#   'colony',
#   'establish',
#   'along',
#   'east',
#   'coast',
#   'following',
#   'french',
#   'indian',
#   'war',
#   'numerous',
#   'dispute',
#   'great',
#   'britain',
#   'colony',
#   'led',
#   'american',
#   'revolution',
#   'begin',
#   'subsequent',
#   'declaration',
#   'independence',
#   'war',
#   'end',
#   'unite',
#   'state',
#   'become',
#   'first',
#   'country',
#   'gain',
#   'independence',
#   'european',
#   'power',
#   'current',
#   'constitution',
#   'wa',
#   'adopt',
#   'first',
#   'ten',
#   'amendment',
#   'collectively',
#   'name',
#   'bill',
#   'right',
#   'ratify',
#   'guarantee',
#   'many',
#   'fundamental',
#   'civil',
#   'liberty',
#   'unite',
#   'state',
#   'embark',
#   'vigorous',
#   'expansion',
#   'across',
#   'north',
#   'america',
#   'throughout',
#   'th',
#   'century',
#   'acquiring',
#   'new',
#   'territory',
#   'displace',
#   'native',
#   'american',
#   'tribe',
#   'gradually',
#   'admit',
#   'new',
#   'state',
#   'span',
#   'continent',
#   'second',
#   'half',
#   'th',
#   'century',
#   'civil',
#   'war',
#   'led',
#   'abolition',
#   'slavery',
#   'end',
#   'century',
#   'unite',
#   'state',
#   'extend',
#   'pacific',
#   'ocean',
#   'economy',
#   'drive',
#   'large',
#   'part',
#   'industrial',
#   'revolution',
#   'begin',
#   'soar',
#   'spanish–american',
#   'war',
#   'world',
#   'war',
#   'confirm',
#   "country's",
#   'status',
#   'global',
#   'military',
#   'power',
#   'unite',
#   'state',
#   'emerge',
#   'world',
#   'war',
#   'ii',
#   'global',
#   'superpower',
#   'first',
#   'country',
#   'develop',
#   'nuclear',
#   'weapon',
#   'country',
#   'use',
#   'warfare',
#   'permanent',
#   'member',
#   'unite',
#   'nation',
#   'security',
#   'council',
#   'sweeping',
#   'civil',
#   'right',
#   'legislation',
#   'notably',
#   'civil',
#   'right',
#   'act',
#   'voting',
#   'right',
#   'act',
#   'fair',
#   'housing',
#   'act',
#   'outlaw',
#   'discrimination',
#   'base',
#   'race',
#   'color',
#   'cold',
#   'war',
#   'unite',
#   'state',
#   'soviet',
#   'union',
#   'compete',
#   'space',
#   'race',
#   'culminate',
#   'us',
#   'moon',
#   'landing',
#   'end',
#   'cold',
#   'war',
#   'collapse',
#   'soviet',
#   'union',
#   'left',
#   'unite',
#   'state',
#   "world's",
#   'sole',
#   'superpower',
#   'unite',
#   'state',
#   "world's",
#   'old',
#   'survive',
#   'federation',
#   'federal',
#   'republic',
#   'representative',
#   'democracy',
#   'unite',
#   'state',
#   'founding',
#   'member',
#   'unite',
#   'nation',
#   'world',
#   'bank',
#   'international',
#   'monetary',
#   'fund',
#   'organization',
#   'american',
#   'state',
#   '(oas)',
#   'international',
#   'organization',
#   'unite',
#   'state',
#   'highly',
#   'develop',
#   'country',
#   "world's",
#   'large',
#   'economy',
#   'nominal',
#   'gdp',
#   'second-largest',
#   'economy',
#   'ppp',
#   'accounting',
#   'approximately',
#   'quarter',
#   'global',
#   'gdp',
#   'us',
#   'economy',
#   'largely',
#   'post-industrial',
#   'characterize',
#   'dominance',
#   'services',
#   'knowledge-based',
#   'activity',
#   'although',
#   'manufacturing',
#   'sector',
#   'remains',
#   'second-largest',
#   'world',
#   'unite',
#   'state',
#   "world's",
#   'large',
#   'importer',
#   'second',
#   'large',
#   'exporter',
#   'good',
#   'value',
#   'although',
#   'population',
#   'world',
#   'total',
#   'us',
#   'hold',
#   'total',
#   'wealth',
#   'world',
#   'large',
#   'share',
#   'global',
#   'wealth',
#   'concentrate',
#   'single',
#   'country',
#   'despite',
#   'income',
#   'wealth',
#   'disparity',
#   'unite',
#   'state',
#   'continue',
#   'rank',
#   'high',
#   'measure',
#   'socioeconomic',
#   'performance',
#   'include',
#   'average',
#   'wage',
#   'human',
#   'development',
#   'per',
#   'caput',
#   'gdp',
#   'worker',
#   'productivity',
#   'unite',
#   'state',
#   'foremost',
#   'military',
#   'power',
#   'world',
#   'making',
#   'third',
#   'global',
#   'military',
#   'spending',
#   'leading',
#   'political',
#   'cultural',
#   'scientific',
#   'force',
#   'internationally'],
#  ['england',
#   'country',
#   'part',
#   'unite',
#   'kingdom',
#   'share',
#   'land',
#   'border',
#   'wales',
#   'west',
#   'scotland',
#   'north',
#   'irish',
#   'sea',
#   'lie',
#   'west',
#   'england',
#   'celtic',
#   'sea',
#   'southwest',
#   'england',
#   'separate',
#   'continental',
#   'europe',
#   'north',
#   'sea',
#   'east',
#   'english',
#   'channel',
#   'south',
#   'country',
#   'cover',
#   'five-eighths',
#   'island',
#   'great',
#   'britain',
#   'lie',
#   'north',
#   'atlantic',
#   'include',
#   'smaller',
#   'island',
#   'isle',
#   'scilly',
#   'isle',
#   'wight',
#   'area',
#   'call',
#   'england',
#   'wa',
#   'first',
#   'inhabit',
#   'modern',
#   'humans',
#   'upper',
#   'palaeolithic',
#   'period',
#   'take',
#   'name',
#   'angle',
#   'germanic',
#   'tribe',
#   'deriving',
#   'name',
#   'anglia',
#   'peninsula',
#   'settle',
#   'th',
#   'th',
#   'century',
#   'england',
#   'become',
#   'unify',
#   'state',
#   'th',
#   'century',
#   'since',
#   'age',
#   'discovery',
#   'begin',
#   'th',
#   'century',
#   'ha',
#   'significant',
#   'cultural',
#   'legal',
#   'impact',
#   'wide',
#   'world',
#   'english',
#   'language',
#   'anglican',
#   'church',
#   'english',
#   'law',
#   '–',
#   'basis',
#   'common',
#   'law',
#   'legal',
#   'system',
#   'many',
#   'country',
#   'around',
#   'world',
#   '–',
#   'develop',
#   'england',
#   "country's",
#   'parliamentary',
#   'system',
#   'government',
#   'ha',
#   'widely',
#   'adopt',
#   'nation',
#   'industrial',
#   'revolution',
#   'begin',
#   'th-century',
#   'england',
#   'transform',
#   'society',
#   "world's",
#   'first',
#   'industrialise',
#   'nation',
#   "england's",
#   'terrain',
#   'chiefly',
#   'low',
#   'hill',
#   'plain',
#   'especially',
#   'central',
#   'southern',
#   'england',
#   'however',
#   'upland',
#   'mountainous',
#   'terrain',
#   'north',
#   '(for',
#   'example',
#   'lake',
#   'district',
#   'pennines)',
#   'west',
#   '(for',
#   'example',
#   'dartmoor',
#   'shropshire',
#   'hills)',
#   'capital',
#   'london',
#   'ha',
#   'large',
#   'metropolitan',
#   'area',
#   'unite',
#   'kingdom',
#   'european',
#   'union[nb',
#   ']',
#   "england's",
#   'population',
#   'million',
#   'comprise',
#   'population',
#   'unite',
#   'kingdom',
#   'largely',
#   'concentrate',
#   'around',
#   'london',
#   'south',
#   'east',
#   'conurbation',
#   'midland',
#   'north',
#   'west',
#   'north',
#   'east',
#   'yorkshire',
#   'develop',
#   'major',
#   'industrial',
#   'region',
#   'th',
#   'century',
#   'kingdom',
#   'england',
#   '–',
#   'include',
#   'wales',
#   '–',
#   'cease',
#   'separate',
#   'sovereign',
#   'state',
#   'may',
#   'acts',
#   'union',
#   'put',
#   'effect',
#   'terms',
#   'agree',
#   'treaty',
#   'union',
#   'previous',
#   'year',
#   'result',
#   'political',
#   'union',
#   'kingdom',
#   'scotland',
#   'create',
#   'kingdom',
#   'great',
#   'britain',
#   'great',
#   'britain',
#   'wa',
#   'unite',
#   'kingdom',
#   'ireland',
#   '(through',
#   'another',
#   'act',
#   'union)',
#   'become',
#   'unite',
#   'kingdom',
#   'great',
#   'britain',
#   'ireland',
#   'irish',
#   'free',
#   'state',
#   'secede',
#   'unite',
#   'kingdom',
#   'leading',
#   'latter',
#   'rename',
#   'unite',
#   'kingdom',
#   'great',
#   'britain',
#   'northern',
#   'ireland'],
#  ['china',
#   'officially',
#   "people's",
#   'republic',
#   'china',
#   '(prc)',
#   'country',
#   'east',
#   'asia',
#   "world's",
#   'populous',
#   'country',
#   'population',
#   'around',
#   'billion',
#   'covering',
#   'approximately',
#   'square',
#   'kilometer',
#   '(',
#   'sq',
#   'mi)',
#   'third-',
#   'fourth-largest',
#   'country',
#   'total',
#   'area[k]',
#   'governed',
#   'communist',
#   'party',
#   'china',
#   'state',
#   'exercise',
#   'jurisdiction',
#   'province',
#   'five',
#   'autonomous',
#   'region',
#   'four',
#   'direct-controlled',
#   'municipality',
#   '(beijing',
#   'tianjin',
#   'shanghai',
#   'chongqing)',
#   'special',
#   'administrative',
#   'region',
#   'hong',
#   'kong',
#   'macau',
#   'china',
#   'emerge',
#   'one',
#   "world's",
#   'earliest',
#   'civilization',
#   'fertile',
#   'basin',
#   'yellow',
#   'river',
#   'north',
#   'china',
#   'plain',
#   'millennium',
#   "china's",
#   'political',
#   'system',
#   'wa',
#   'base',
#   'hereditary',
#   'monarchy',
#   'dynasty',
#   'beginning',
#   'semi-legendary',
#   'xia',
#   'dynasty',
#   'st',
#   'century',
#   'bce',
#   'since',
#   'china',
#   'ha',
#   'expand',
#   'fracture',
#   're-unified',
#   'numerous',
#   'times',
#   'rd',
#   'century',
#   'bce',
#   'qin',
#   'reunite',
#   'core',
#   'china',
#   'establish',
#   'first',
#   'chinese',
#   'empire',
#   'succeed',
#   'han',
#   'dynasty',
#   'rule',
#   'bc',
#   'ad',
#   'saw',
#   'advance',
#   'technology',
#   'time',
#   'include',
#   'papermaking',
#   'compass',
#   'along',
#   'agricultural',
#   'medical',
#   'improvement',
#   'invention',
#   'gunpowder',
#   'movable',
#   'type',
#   'tang',
#   'dynasty',
#   '(–)',
#   'northern',
#   'song',
#   '(–)',
#   'complete',
#   'four',
#   'great',
#   'invention',
#   'tang',
#   'culture',
#   'spread',
#   'widely',
#   'asia',
#   'new',
#   'silk',
#   'route',
#   'bring',
#   'trader',
#   'far',
#   'mesopotamia',
#   'horn',
#   'africa',
#   'dynastic',
#   'rule',
#   'end',
#   'xinhai',
#   'revolution',
#   'republic',
#   'replace',
#   'qing',
#   'dynasty',
#   'china',
#   'whole',
#   'wa',
#   'ravage',
#   'japan',
#   'world',
#   'war',
#   'ii',
#   'subsequent',
#   'chinese',
#   'civil',
#   'war',
#   'result',
#   'division',
#   'territory',
#   'communist',
#   'party',
#   'china',
#   'establish',
#   "people's",
#   'republic',
#   'china',
#   'unitary',
#   'one-party',
#   'sovereign',
#   'state',
#   'majority',
#   'china',
#   'kuomintang-led',
#   'nationalist',
#   'government',
#   'retreated',
#   'island',
#   'taiwan',
#   'political',
#   'status',
#   'taiwan',
#   'remains',
#   'dispute',
#   'since',
#   'introduction',
#   'economic',
#   'reform',
#   "china's",
#   'economy',
#   'ha',
#   'one',
#   "world's",
#   'fastest-growing',
#   'annual',
#   'growth',
#   'rates',
#   'consistently',
#   'percent',
#   'accord',
#   'world',
#   'bank',
#   "china's",
#   'gdp',
#   'grow',
#   '$',
#   'billion',
#   '$',
#   'trillion',
#   'accord',
#   'official',
#   'data',
#   "china's",
#   'gdp',
#   'wa',
#   'trillion',
#   'yuan',
#   '($',
#   'trillion)',
#   'since',
#   'china',
#   'ha',
#   "world's",
#   'second-largest',
#   'economy',
#   'nominal',
#   'gdp',
#   'since',
#   'large',
#   'economy',
#   'world',
#   'purchasing',
#   'power',
#   'parity',
#   '(ppp)',
#   'china',
#   'also',
#   "world's",
#   'large',
#   'exporter',
#   'second-largest',
#   'importer',
#   'good',
#   'china',
#   'recognize',
#   'nuclear',
#   'weapon',
#   'state',
#   'ha',
#   "world's",
#   'large',
#   'standing',
#   'army',
#   'second-largest',
#   'defense',
#   'budget',
#   'prc',
#   'permanent',
#   'member',
#   'unite',
#   'nation',
#   'security',
#   'council',
#   'replace',
#   'roc',
#   'well',
#   'active',
#   'global',
#   'partner',
#   'asean',
#   'plus',
#   'mechanism',
#   'china',
#   'also',
#   'leading',
#   'member',
#   'numerous',
#   'formal',
#   'informal',
#   'multilateral',
#   'organization',
#   'include',
#   'shanghai',
#   'cooperation',
#   'organization',
#   '(sco)',
#   'wto',
#   'apec',
#   'brics',
#   'bcim',
#   'g',
#   'china',
#   'ha',
#   'widely',
#   'characterize',
#   'global',
#   'superpower',
#   'rival',
#   'unite',
#   'state'],
#  ['india',
#   'also',
#   'know',
#   'republic',
#   'india[e]',
#   'country',
#   'south',
#   'asia',
#   'seventh-largest',
#   'country',
#   'area',
#   'second-most',
#   'populous',
#   'country',
#   'populous',
#   'democracy',
#   'world',
#   'bound',
#   'indian',
#   'ocean',
#   'south',
#   'arabian',
#   'sea',
#   'southwest',
#   'bay',
#   'bengal',
#   'southeast',
#   'share',
#   'land',
#   'border',
#   'pakistan',
#   'west;[f]',
#   'china',
#   'nepal',
#   'bhutan',
#   'northeast;',
#   'bangladesh',
#   'myanmar',
#   'east',
#   'indian',
#   'ocean',
#   'india',
#   'vicinity',
#   'sri',
#   'lanka',
#   'maldives;',
#   'andaman',
#   'nicobar',
#   'island',
#   'share',
#   'maritime',
#   'border',
#   'thailand',
#   'indonesia',
#   'indian',
#   'subcontinent',
#   'wa',
#   'home',
#   'indus',
#   'valley',
#   'civilisation',
#   'bronze',
#   'age',
#   "india's",
#   'iron',
#   'age',
#   'old',
#   'scripture',
#   'hinduism',
#   'compose',
#   'social',
#   'stratification',
#   'base',
#   'caste',
#   'emerge',
#   'buddhism',
#   'jainism',
#   'arise',
#   'political',
#   'consolidation',
#   'take',
#   'place',
#   'maurya',
#   'gupta',
#   'empires;',
#   'peninsular',
#   'middle',
#   'kingdom',
#   'influence',
#   'culture',
#   'southeast',
#   'asia',
#   "india's",
#   'medieval',
#   'era',
#   'judaism',
#   'zoroastrianism',
#   'christianity',
#   'islam',
#   'arrive',
#   'sikhism',
#   'emerge',
#   'add',
#   'diverse',
#   'culture',
#   'north',
#   'india',
#   'fell',
#   'delhi',
#   'sultanate;',
#   'south',
#   'india',
#   'wa',
#   'unite',
#   'vijayanagara',
#   'empire',
#   'early',
#   'modern',
#   'era',
#   'expansive',
#   'mughal',
#   'empire',
#   'wa',
#   'follow',
#   'east',
#   'india',
#   'company',
#   'rule',
#   "india's",
#   'modern',
#   'age',
#   'wa',
#   'mark',
#   'british',
#   'crown',
#   'rule',
#   'nationalist',
#   'movement',
#   'mahatma',
#   'gandhi',
#   'wa',
#   'note',
#   'nonviolence',
#   'led',
#   "india's",
#   'independence',
#   'economic',
#   'liberalisation',
#   'begin',
#   'ha',
#   'cause',
#   'india',
#   'become',
#   'fast',
#   'growing',
#   'major',
#   'economy',
#   'newly',
#   'industrialise',
#   'country',
#   'gross',
#   'domestic',
#   'product',
#   'rank',
#   'sixth',
#   'world',
#   'market',
#   'exchange',
#   'rates',
#   'third',
#   'purchasing',
#   'power',
#   'parity',
#   'per',
#   'caput',
#   'income',
#   'rank',
#   'rd',
#   'th',
#   'two',
#   'measure',
#   'india',
#   'face',
#   'challenge',
#   'poverty',
#   'corruption',
#   'malnutrition',
#   'inadequate',
#   'public',
#   'healthcare',
#   'nuclear',
#   'weapon',
#   'state',
#   'regional',
#   'power',
#   'ha',
#   'second',
#   'large',
#   'active',
#   'military',
#   'world',
#   'rank',
#   'high',
#   'military',
#   'expenditure',
#   'india',
#   'secular',
#   'federal',
#   'republic',
#   'governed',
#   'democratic',
#   'parliamentary',
#   'system',
#   'administer',
#   'state',
#   'seven',
#   'union',
#   'territory',
#   'pluralistic',
#   'multilingual',
#   'multi-ethnic',
#   'society',
#   'india',
#   'home',
#   'billion',
#   'people',
#   'also',
#   'home',
#   'high',
#   'diversity',
#   'wildlife',
#   'variety',
#   'protect',
#   'habitat'],
#  ['korea',
#   'region',
#   'east',
#   'asia',
#   'since',
#   'ha',
#   'divide',
#   'two',
#   'distinct',
#   'sovereign',
#   'state',
#   'north',
#   'korea',
#   'south',
#   'korea',
#   'korea',
#   'consist',
#   'korean',
#   'peninsula',
#   'jeju',
#   'island',
#   'several',
#   'minor',
#   'island',
#   'near',
#   'peninsula',
#   'korea',
#   'border',
#   'russia',
#   'northeast',
#   'china',
#   'northwest',
#   'japan',
#   'east',
#   'via',
#   'korea',
#   'strait',
#   'sea',
#   'japan',
#   '(east',
#   'sea)',
#   'first',
#   'half',
#   'st',
#   'millennium',
#   'korea',
#   'wa',
#   'divide',
#   'three',
#   'compete',
#   'state',
#   'goguryeo',
#   'baekje',
#   'silla',
#   'together',
#   'know',
#   '"three',
#   'kingdom',
#   'korea"',
#   'second',
#   'half',
#   'st',
#   'millennium',
#   'silla',
#   'defeated',
#   'conquer',
#   'baekje',
#   'goguryeo',
#   'leading',
#   '"unified',
#   'silla"',
#   'period',
#   'meanwhile',
#   'balhae',
#   'form',
#   'north',
#   'supersede',
#   'former',
#   'goguryeo',
#   'unify',
#   'silla',
#   'eventually',
#   'collapse',
#   'three',
#   'separate',
#   'state',
#   'due',
#   'civil',
#   'war',
#   'usher',
#   'later',
#   'three',
#   'kingdom',
#   'toward',
#   'end',
#   'st',
#   'millennium',
#   'goguryeo',
#   'wa',
#   'resurrect',
#   'goryeo',
#   'defeated',
#   'two',
#   'state',
#   'unify',
#   'korean',
#   'peninsula',
#   'single',
#   'sovereign',
#   'state',
#   'around',
#   'time',
#   'balhae',
#   'collapse',
#   'last',
#   'crown',
#   'prince',
#   'flee',
#   'south',
#   'goryeo',
#   'goryeo',
#   '(also',
#   'spell',
#   'koryŏ)',
#   'whose',
#   'name',
#   'develop',
#   'modern',
#   'exonym',
#   '"korea"',
#   'wa',
#   'highly',
#   'culture',
#   'state',
#   'create',
#   "world's",
#   'first',
#   'metal',
#   'movable',
#   'type',
#   'however',
#   'multiple',
#   'incursion',
#   'mongol',
#   'empire',
#   'th',
#   'century',
#   'greatly',
#   'weaken',
#   'nation',
#   'eventually',
#   'agree',
#   'become',
#   'vassal',
#   'state',
#   'decade',
#   'fighting',
#   'following',
#   'military',
#   'resistance',
#   'king',
#   'gongmin',
#   'end',
#   'mongol',
#   'political',
#   'influence',
#   'goryeo',
#   'severe',
#   'political',
#   'strife',
#   'follow',
#   'goryeo',
#   'eventually',
#   'fell',
#   'coup',
#   'led',
#   'general',
#   'yi',
#   'seong-gye',
#   'establish',
#   'joseon',
#   'july',
#   'first',
#   'years',
#   'joseon',
#   'era',
#   'mark',
#   'relative',
#   'peace',
#   'period',
#   'korean',
#   'alphabet',
#   'wa',
#   'create',
#   'sejong',
#   'great',
#   'th',
#   'century',
#   'wa',
#   'increase',
#   'influence',
#   'confucianism',
#   'later',
#   'part',
#   'dynasty',
#   "korea's",
#   'isolationist',
#   'policy',
#   'earn',
#   'western',
#   'nickname',
#   '"hermit',
#   'kingdom"',
#   'late',
#   'th',
#   'century',
#   'country',
#   'become',
#   'object',
#   'imperial',
#   'design',
#   'empire',
#   'japan',
#   'first',
#   'sino-japanese',
#   'war',
#   'despite',
#   'korean',
#   "empire's",
#   'effort',
#   'modernize',
#   'country',
#   'wa',
#   'annex',
#   'japan',
#   'rule',
#   'end',
#   'world',
#   'war',
#   'ii',
#   'august',
#   'soviet',
#   'union',
#   'unite',
#   'state',
#   'agree',
#   'surrender',
#   'japanese',
#   'force',
#   'korea',
#   'aftermath',
#   'world',
#   'war',
#   'ii',
#   'leaving',
#   'korea',
#   'partition',
#   'along',
#   'th',
#   'parallel',
#   'north',
#   'wa',
#   'soviet',
#   'occupation',
#   'south',
#   'us',
#   'occupation',
#   'circumstances',
#   'soon',
#   'become',
#   'basis',
#   'division',
#   'korea',
#   'two',
#   'superpower',
#   'exacerbate',
#   'inability',
#   'agree',
#   'terms',
#   'korean',
#   'independence',
#   'communist-inspired',
#   'government',
#   'north',
#   'receive',
#   'backing',
#   'soviet',
#   'union',
#   'opposition',
#   'pro-western',
#   'government',
#   'south',
#   'leading',
#   "korea's",
#   'division',
#   'two',
#   'political',
#   'entities:',
#   'north',
#   'korea',
#   '(officially',
#   'democratic',
#   "people's",
#   'republic',
#   'korea)',
#   'south',
#   'korea',
#   '(officially',
#   'republic',
#   'korea)',
#   'tension',
#   'two',
#   'result',
#   'outbreak',
#   'korean',
#   'war',
#   'involvement',
#   'foreign',
#   'troops',
#   'war',
#   'end',
#   'stalemate',
#   'without',
#   'formalize',
#   'peace',
#   'treaty',
#   'status',
#   'contribute',
#   'high',
#   'tension',
#   'continue',
#   'divide',
#   'peninsula',
#   'government',
#   'two',
#   'korea',
#   'claim',
#   'sole',
#   'legitimate',
#   'government',
#   'region'],
#  ['germany',
#   'officially',
#   'federal',
#   'republic',
#   'germany',
#   'country',
#   'central',
#   'western',
#   'europe',
#   'lying',
#   'baltic',
#   'north',
#   'sea',
#   'north',
#   'alps',
#   'lake',
#   'constance',
#   'high',
#   'rhine',
#   'south',
#   'border',
#   'denmark',
#   'north',
#   'poland',
#   'czech',
#   'republic',
#   'east',
#   'austria',
#   'switzerland',
#   'south',
#   'france',
#   'southwest',
#   'luxembourg',
#   'belgium',
#   'netherlands',
#   'west',
#   'germany',
#   'include',
#   'constituent',
#   'state',
#   'cover',
#   'area',
#   'square',
#   'kilometre',
#   '(',
#   'sq',
#   'mi)',
#   'ha',
#   'largely',
#   'temperate',
#   'seasonal',
#   'climate',
#   'million',
#   'inhabitant',
#   'second',
#   'populous',
#   'state',
#   'europe',
#   'russia',
#   'populous',
#   'state',
#   'lying',
#   'entirely',
#   'europe',
#   'well',
#   'populous',
#   'member',
#   'state',
#   'european',
#   'union',
#   'germany',
#   'decentralize',
#   'country',
#   'capital',
#   'large',
#   'metropolis',
#   'berlin',
#   'frankfurt',
#   'serve',
#   'financial',
#   'capital',
#   'ha',
#   "country's",
#   'busy',
#   'airport',
#   "germany's",
#   'large',
#   'urban',
#   'area',
#   'ruhr',
#   'main',
#   'centre',
#   'dortmund',
#   'essen',
#   "country's",
#   'major',
#   'city',
#   'include',
#   'hamburg',
#   'munich',
#   'cologne',
#   'stuttgart',
#   'düsseldorf',
#   'leipzig',
#   'dresden',
#   'bremen',
#   'hannover',
#   'nuremberg',
#   'mannheim',
#   'various',
#   'germanic',
#   'tribe',
#   'inhabit',
#   'northern',
#   'parts',
#   'modern',
#   'germany',
#   'since',
#   'classical',
#   'antiquity',
#   'region',
#   'name',
#   'germania',
#   'wa',
#   'document',
#   'ad',
#   'migration',
#   'period',
#   'germanic',
#   'tribe',
#   'expand',
#   'southward',
#   'beginning',
#   'th',
#   'century',
#   'german',
#   'territory',
#   'form',
#   'central',
#   'part',
#   'holy',
#   'roman',
#   'empire',
#   'th',
#   'century',
#   'northern',
#   'german',
#   'region',
#   'become',
#   'centre',
#   'protestant',
#   'reformation',
#   'collapse',
#   'holy',
#   'roman',
#   'empire',
#   'german',
#   'confederation',
#   'wa',
#   'form',
#   'german',
#   'revolution',
#   '–',
#   'result',
#   'frankfurt',
#   'parliament',
#   'establish',
#   'major',
#   'democratic',
#   'right',
#   'germany',
#   'become',
#   'nation',
#   'state',
#   'german',
#   'state',
#   'unify',
#   '(except',
#   'switzerland',
#   'austria)',
#   'prussian-dominated',
#   'german',
#   'empire',
#   'world',
#   'war',
#   'revolution',
#   '–',
#   'empire',
#   'wa',
#   'replace',
#   'parliamentary',
#   'weimar',
#   'republic',
#   'nazi',
#   'seizure',
#   'power',
#   'led',
#   'establishment',
#   'dictatorship',
#   'annexation',
#   'austria',
#   'world',
#   'war',
#   'ii',
#   'holocaust',
#   'end',
#   'world',
#   'war',
#   'ii',
#   'europe',
#   'period',
#   'ally',
#   'occupation',
#   'austria',
#   'wa',
#   're-established',
#   'independent',
#   'country',
#   'two',
#   'new',
#   'german',
#   'state',
#   'founded:',
#   'west',
#   'germany',
#   'form',
#   'american',
#   'british',
#   'french',
#   'occupation',
#   'zone',
#   'east',
#   'germany',
#   'form',
#   'soviet',
#   'occupation',
#   'zone',
#   'quarter',
#   "germany's",
#   'pre-war',
#   'territory',
#   'wa',
#   'annex',
#   'poland',
#   'soviet',
#   'union',
#   'leading',
#   'explusion',
#   'german',
#   'following',
#   'revolution',
#   'end',
#   'communist',
#   'rule',
#   'central',
#   'eastern',
#   'europe',
#   'country',
#   'wa',
#   'reunify',
#   'october',
#   'today',
#   'sovereign',
#   'state',
#   'germany',
#   'federal',
#   'parliamentary',
#   'republic',
#   'led',
#   'chancellor',
#   'great',
#   'power',
#   'strong',
#   'economy;',
#   'ha',
#   "world's",
#   'fourth-largest',
#   'economy',
#   'nominal',
#   'gdp',
#   'fifth-largest',
#   'ppp',
#   'global',
#   'leader',
#   'several',
#   'industrial',
#   'technological',
#   'sector',
#   "world's",
#   'third-largest',
#   'exporter',
#   'importer',
#   'good',
#   'develop',
#   'country',
#   'high',
#   'standard',
#   'living',
#   'uphold',
#   'social',
#   'security',
#   'universal',
#   'health',
#   'care',
#   'system',
#   'environmental',
#   'protection',
#   'tuition-free',
#   'university',
#   'education',
#   'federal',
#   'republic',
#   'germany',
#   'wa',
#   'founding',
#   'member',
#   'european',
#   'economic',
#   'community',
#   'european',
#   'union',
#   'part',
#   'schengen',
#   'area',
#   'become',
#   'co-founder',
#   'eurozone',
#   'germany',
#   'member',
#   'unite',
#   'nation',
#   'nato',
#   'g',
#   'g',
#   'oecd',
#   'know',
#   'rich',
#   'cultural',
#   'history',
#   'germany',
#   'ha',
#   'continuously',
#   'home',
#   'influential',
#   'successful',
#   'artist',
#   'philosopher',
#   'musician',
#   'film',
#   'people',
#   'sportspeople',
#   'entrepreneur',
#   'scientist',
#   'engineer',
#   'inventor',
#   'germany',
#   'ha',
#   'large',
#   'number',
#   'world',
#   'heritage',
#   'site',
#   'among',
#   'top',
#   'tourism',
#   'destination',
#   'world'],
#  ['russia',
#   'russian',
#   'federation',
#   'transcontinental',
#   'country',
#   'eastern',
#   'europe',
#   'north',
#   'asia',
#   'square',
#   'kilometre',
#   '(',
#   'sq',
#   'mi)',
#   'russia',
#   'considerable',
#   'margin',
#   'large',
#   'country',
#   'world',
#   'area',
#   'covering',
#   'one-eighth',
#   "earth's",
#   'inhabit',
#   'land',
#   'area',
#   'ninth',
#   'populous',
#   'million',
#   'people',
#   'include',
#   'crimea',
#   'population',
#   'live',
#   'western',
#   'european',
#   'part',
#   'country',
#   "russia's",
#   'capital',
#   'moscow',
#   'one',
#   'large',
#   'city',
#   'world',
#   'second',
#   'large',
#   'city',
#   'europe;',
#   'major',
#   'city',
#   'include',
#   'saint',
#   'petersburg',
#   'novosibirsk',
#   'yekaterinburg',
#   'nizhny',
#   'novgorod',
#   'extend',
#   'across',
#   'entirety',
#   'northern',
#   'asia',
#   'much',
#   'eastern',
#   'europe',
#   'russia',
#   'span',
#   'eleven',
#   'time',
#   'zone',
#   'incorporate',
#   'wide',
#   'range',
#   'environment',
#   'landforms',
#   'northwest',
#   'southeast',
#   'russia',
#   'share',
#   'land',
#   'border',
#   'norway',
#   'finland',
#   'estonia',
#   'latvia',
#   'lithuania',
#   'poland',
#   '(both',
#   'kaliningrad',
#   'oblast)',
#   'belarus',
#   'ukraine',
#   'georgia',
#   'azerbaijan',
#   'kazakhstan',
#   'china',
#   'mongolia',
#   'north',
#   'korea',
#   'share',
#   'maritime',
#   'border',
#   'japan',
#   'sea',
#   'okhotsk',
#   'us',
#   'state',
#   'alaska',
#   'across',
#   'bering',
#   'strait',
#   'however',
#   'russia',
#   'recognise',
#   'two',
#   'country',
#   'border',
#   'abkhazia',
#   'south',
#   'ossetia',
#   'internationally',
#   'recognize',
#   'parts',
#   'georgia',
#   'east',
#   'slav',
#   'emerge',
#   'recognizable',
#   'group',
#   'europe',
#   'rd',
#   'th',
#   'century',
#   'ad',
#   'found',
#   'rule',
#   'varangian',
#   'warrior',
#   'elite',
#   'descendants',
#   'medieval',
#   'state',
#   'rus',
#   'arise',
#   'th',
#   'century',
#   'adopt',
#   'orthodox',
#   'christianity',
#   'byzantine',
#   'empire',
#   'beginning',
#   'synthesis',
#   'byzantine',
#   'slavic',
#   'culture',
#   'define',
#   'russian',
#   'culture',
#   'next',
#   'millennium',
#   'rus',
#   'ultimately',
#   'disintegrate',
#   'number',
#   'smaller',
#   'states;',
#   "rus'",
#   'land',
#   'overrun',
#   'mongol',
#   'invasion',
#   'become',
#   'tributary',
#   'nomadic',
#   'golden',
#   'horde',
#   'th',
#   'century',
#   'grand',
#   'duchy',
#   'moscow',
#   'gradually',
#   'reunify',
#   'surround',
#   'russian',
#   'principality',
#   'achieve',
#   'independence',
#   'golden',
#   'horde',
#   'th',
#   'century',
#   'nation',
#   'greatly',
#   'expand',
#   'conquest',
#   'annexation',
#   'exploration',
#   'become',
#   'russian',
#   'empire',
#   'wa',
#   'third',
#   'large',
#   'empire',
#   'history',
#   'stretching',
#   'poland',
#   'west',
#   'alaska',
#   'east',
#   'following',
#   'russian',
#   'revolution',
#   'russian',
#   'soviet',
#   'federative',
#   'socialist',
#   'republic',
#   'become',
#   'large',
#   'leading',
#   'constituent',
#   'union',
#   'soviet',
#   'socialist',
#   'republic',
#   "world's",
#   'first',
#   'constitutionally',
#   'socialist',
#   'state',
#   'soviet',
#   'union',
#   'play',
#   'decisive',
#   'role',
#   'ally',
#   'victory',
#   'world',
#   'war',
#   'ii',
#   'emerge',
#   'recognize',
#   'superpower',
#   'rival',
#   'unite',
#   'state',
#   'cold',
#   'war',
#   'soviet',
#   'era',
#   'saw',
#   'significant',
#   'technological',
#   'achievement',
#   'th',
#   'century',
#   'include',
#   "world's",
#   'first',
#   'human-made',
#   'satellite',
#   'launching',
#   'first',
#   'humans',
#   'space',
#   'end',
#   'soviet',
#   'union',
#   "world's",
#   'second',
#   'large',
#   'economy',
#   'large',
#   'standing',
#   'military',
#   'world',
#   'large',
#   'stockpile',
#   'weapon',
#   'mass',
#   'destruction',
#   'following',
#   'dissolution',
#   'soviet',
#   'union',
#   'twelve',
#   'independent',
#   'republic',
#   'emerge',
#   'ussr:',
#   'russia',
#   'ukraine',
#   'belarus',
#   'kazakhstan',
#   'uzbekistan',
#   'armenia',
#   'azerbaijan',
#   'georgia',
#   'kyrgyzstan',
#   'moldova',
#   'tajikistan',
#   'turkmenistan',
#   'baltic',
#   'state',
#   'regain',
#   'independence:',
#   'estonia',
#   'latvia',
#   'lithuania;',
#   'russian',
#   'sfsr',
#   'reconstitute',
#   'russian',
#   'federation',
#   'recognize',
#   'continue',
#   'legal',
#   'personality',
#   'successor',
#   'soviet',
#   'union',
#   'governed',
#   'federal',
#   'semi-presidential',
#   'republic',
#   "russia's",
#   'economy',
#   'rank',
#   'twelfth',
#   'large',
#   'nominal',
#   'gdp',
#   'sixth',
#   'large',
#   'purchasing',
#   'power',
#   'parity',
#   "russia's",
#   'extensive',
#   'mineral',
#   'energy',
#   'resource',
#   'large',
#   'reserves',
#   'world',
#   'making',
#   'one',
#   'leading',
#   'producer',
#   'oil',
#   'natural',
#   'gas',
#   'globally',
#   'country',
#   'one',
#   'five',
#   'recognize',
#   'nuclear',
#   'weapon',
#   'state',
#   'posse',
#   'large',
#   'stockpile',
#   'weapon',
#   'mass',
#   'destruction',
#   'russia',
#   'great',
#   'power',
#   'well',
#   'regional',
#   'power',
#   'ha',
#   'characterise',
#   'potential',
#   'superpower',
#   'permanent',
#   'member',
#   'unite',
#   'nation',
#   'security',
#   'council',
#   'active',
#   'global',
#   'partner',
#   'asean',
#   'well',
#   'member',
#   'shanghai',
#   'cooperation',
#   'organisation',
#   '(sco)',
#   'g',
#   'council',
#   'europe',
#   'asia-pacific',
#   'economic',
#   'cooperation',
#   '(apec)',
#   'organization',
#   'security',
#   'co-operation',
#   'europe',
#   '(osce)',
#   'world',
#   'trade',
#   'organization',
#   '(wto)',
#   'well',
#   'leading',
#   'member',
#   'commonwealth',
#   'independent',
#   'state',
#   '(cis)',
#   'collective',
#   'security',
#   'treaty',
#   'organization',
#   '(csto)',
#   'one',
#   'five',
#   'member',
#   'eurasian',
#   'economic',
#   'union',
#   '(eeu)',
#   'along',
#   'armenia',
#   'belarus',
#   'kazakhstan',
#   'kyrgyzstan'],
#  ['france',
#   'officially',
#   'french',
#   'republic',
#   'country',
#   'whose',
#   'territory',
#   'consist',
#   'metropolitan',
#   'france',
#   'western',
#   'europe',
#   'several',
#   'overseas',
#   'region',
#   'territories[xiii]',
#   'metropolitan',
#   'area',
#   'france',
#   'extend',
#   'mediterranean',
#   'sea',
#   'english',
#   'channel',
#   'north',
#   'sea',
#   'rhine',
#   'atlantic',
#   'ocean',
#   'border',
#   'belgium',
#   'luxembourg',
#   'germany',
#   'northeast',
#   'switzerland',
#   'italy',
#   'east',
#   'andorra',
#   'spain',
#   'south',
#   'overseas',
#   'territory',
#   'include',
#   'french',
#   'guiana',
#   'south',
#   'america',
#   'several',
#   'island',
#   'atlantic',
#   'pacific',
#   'indian',
#   'ocean',
#   "country's",
#   'integral',
#   'region',
#   'span',
#   'combine',
#   'area',
#   'square',
#   'kilometre',
#   '(',
#   'sq',
#   'mi)',
#   'total',
#   'population',
#   'million',
#   '(as',
#   'july',
#   ')',
#   'france',
#   'sovereign',
#   'state',
#   'unitary',
#   'semi-presidential',
#   'republic',
#   'capital',
#   'paris',
#   "country's",
#   'large',
#   'city',
#   'main',
#   'cultural',
#   'commercial',
#   'centre',
#   'major',
#   'urban',
#   'area',
#   'include',
#   'lyon',
#   'marseille',
#   'toulouse',
#   'bordeaux',
#   'lille',
#   'nice',
#   'iron',
#   'age',
#   'metropolitan',
#   'france',
#   'wa',
#   'inhabit',
#   'gaul',
#   'celtic',
#   'people',
#   'rome',
#   'annex',
#   'area',
#   'bc',
#   'holding',
#   'arrival',
#   'germanic',
#   'frank',
#   'form',
#   'kingdom',
#   'francia',
#   'treaty',
#   'verdun',
#   'partition',
#   'francia',
#   'east',
#   'francia',
#   'middle',
#   'francia',
#   'west',
#   'francia',
#   'west',
#   'francia',
#   'become',
#   'kingdom',
#   'france',
#   'emerge',
#   'major',
#   'european',
#   'power',
#   'late',
#   'middle',
#   'age',
#   'following',
#   'victory',
#   'hundred',
#   "years'",
#   'war',
#   '(–)',
#   'renaissance',
#   'french',
#   'culture',
#   'flourish',
#   'global',
#   'colonial',
#   'empire',
#   'wa',
#   'establish',
#   'th',
#   'century',
#   'would',
#   'become',
#   'second',
#   'large',
#   'world',
#   'th',
#   'century',
#   'wa',
#   'dominate',
#   'religious',
#   'civil',
#   'war',
#   'catholic',
#   'protestant',
#   '(huguenots)',
#   'france',
#   'become',
#   "europe's",
#   'dominant',
#   'cultural',
#   'political',
#   'military',
#   'power',
#   'th',
#   'century',
#   'louis',
#   'xiv',
#   'late',
#   'th',
#   'century',
#   'french',
#   'revolution',
#   'overthrow',
#   'absolute',
#   'monarchy',
#   'establish',
#   'one',
#   'modern',
#   "history's",
#   'earliest',
#   'republic',
#   'saw',
#   'drafting',
#   'declaration',
#   'right',
#   'man',
#   'citizen',
#   'express',
#   "nation's",
#   'ideal',
#   'day',
#   'th',
#   'century',
#   'napoleon',
#   'take',
#   'power',
#   'establish',
#   'first',
#   'french',
#   'empire',
#   'subsequent',
#   'napoleonic',
#   'war',
#   '(–)',
#   'shape',
#   'course',
#   'continental',
#   'europe',
#   'following',
#   'collapse',
#   'empire',
#   'france',
#   'endure',
#   'tumultuous',
#   'succession',
#   'government',
#   'culminate',
#   'establishment',
#   'french',
#   'third',
#   'republic',
#   'france',
#   'wa',
#   'major',
#   'participant',
#   'world',
#   'war',
#   'emerge',
#   'victorious',
#   'wa',
#   'one',
#   'allies',
#   'world',
#   'war',
#   'ii',
#   'come',
#   'occupation',
#   'axis',
#   'power',
#   'following',
#   'liberation',
#   'fourth',
#   'republic',
#   'wa',
#   'establish',
#   'later',
#   'dissolve',
#   'course',
#   'algerian',
#   'war',
#   'fifth',
#   'republic',
#   'led',
#   'charles',
#   'de',
#   'gaulle',
#   'wa',
#   'form',
#   'remains',
#   'today',
#   'algeria',
#   'nearly',
#   'colony',
#   'become',
#   'independent',
#   'typically',
#   'retain',
#   'close',
#   'economic',
#   'military',
#   'connection',
#   'france',
#   'france',
#   'ha',
#   'long',
#   'global',
#   'centre',
#   'art',
#   'science',
#   'philosophy',
#   'host',
#   "world's",
#   'fourth-largest',
#   'number',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'leading',
#   'tourist',
#   'destination',
#   'receive',
#   'around',
#   'million',
#   'foreign',
#   'visitor',
#   'annually',
#   'france',
#   'develop',
#   'country',
#   "world's",
#   'sixth-largest',
#   'economy',
#   'nominal',
#   'gdp',
#   'tenth-largest',
#   'purchasing',
#   'power',
#   'parity',
#   'terms',
#   'aggregate',
#   'household',
#   'wealth',
#   'rank',
#   'fourth',
#   'world',
#   'france',
#   'perform',
#   'well',
#   'international',
#   'ranking',
#   'education',
#   'health',
#   'care',
#   'life',
#   'expectancy',
#   'human',
#   'development',
#   'france',
#   'consider',
#   'great',
#   'power',
#   'global',
#   'affairs',
#   'one',
#   'five',
#   'permanent',
#   'member',
#   'unite',
#   'nation',
#   'security',
#   'council',
#   'power',
#   'veto',
#   'official',
#   'nuclear-weapon',
#   'state',
#   'leading',
#   'member',
#   'state',
#   'european',
#   'union',
#   'eurozone',
#   'member',
#   'group',
#   'north',
#   'atlantic',
#   'treaty',
#   'organization',
#   '(nato)',
#   'organisation',
#   'economic',
#   'co-operation',
#   'development',
#   '(oecd)',
#   'world',
#   'trade',
#   'organization',
#   '(wto)',
#   'la',
#   'francophonie'],
#  ['italy',
#   'officially',
#   'italian',
#   'republic',
#   'european',
#   'country',
#   'consist',
#   'peninsula',
#   'delimit',
#   'italian',
#   'alps',
#   'surround',
#   'several',
#   'island',
#   'locate',
#   'middle',
#   'mediterranean',
#   'sea',
#   'traverse',
#   'along',
#   'length',
#   'apennines',
#   'italy',
#   'ha',
#   'largely',
#   'temperate',
#   'seasonal',
#   'climate',
#   'country',
#   'cover',
#   'area',
#   'km',
#   '(',
#   'sq',
#   'mi)',
#   'share',
#   'open',
#   'land',
#   'border',
#   'france',
#   'slovenia',
#   'austria',
#   'switzerland',
#   'enclaved',
#   'microstates',
#   'vatican',
#   'city',
#   'san',
#   'marino',
#   'italy',
#   'ha',
#   'territorial',
#   'exclave',
#   'switzerland',
#   '(campione)',
#   'maritime',
#   'exclave',
#   'tunisian',
#   'sea',
#   '(lampedusa)',
#   'around',
#   'million',
#   'inhabitant',
#   'italy',
#   'fourth-most',
#   'populous',
#   'member',
#   'state',
#   'european',
#   'union',
#   'due',
#   'central',
#   'geographic',
#   'location',
#   'southern',
#   'europe',
#   'mediterranean',
#   'italy',
#   'ha',
#   'historically',
#   'home',
#   'myriad',
#   'ancient',
#   'peoples',
#   'culture',
#   'predominant',
#   'indo-european',
#   'italic',
#   'peoples',
#   'give',
#   'peninsula',
#   'name',
#   'italic',
#   'tribe',
#   'know',
#   'latin',
#   'form',
#   'roman',
#   'kingdom',
#   'th',
#   'century',
#   'bc',
#   'eventually',
#   'become',
#   'republic',
#   'government',
#   'senate',
#   'people',
#   'expand',
#   'conquer',
#   'parts',
#   'europe',
#   'north',
#   'africa',
#   'asia',
#   'first',
#   'century',
#   'bc',
#   'roman',
#   'empire',
#   'emerge',
#   'dominant',
#   'power',
#   'mediterranean',
#   'basin',
#   'become',
#   'leading',
#   'cultural',
#   'political',
#   'religious',
#   'centre',
#   'western',
#   'civilisation',
#   'inaugurate',
#   'pax',
#   'romana',
#   'period',
#   'years',
#   "italy's",
#   'law',
#   'technology',
#   'economy',
#   'art',
#   'literature',
#   'develop',
#   'italy',
#   'remain',
#   'homeland',
#   'romans',
#   'metropole',
#   'empire',
#   'whose',
#   'legacy',
#   'also',
#   'observe',
#   'global',
#   'distribution',
#   'culture',
#   'government',
#   'christianity',
#   'latin',
#   'script',
#   'early',
#   'middle',
#   'age',
#   'italy',
#   'endure',
#   'sociopolitical',
#   'collapse',
#   'barbarian',
#   'invasion',
#   'th',
#   'century',
#   'numerous',
#   'rival',
#   'city-state',
#   'maritime',
#   'republic',
#   'mainly',
#   'northern',
#   'central',
#   'region',
#   'italy',
#   'rose',
#   'great',
#   'prosperity',
#   'trade',
#   'commerce',
#   'banking',
#   'laying',
#   'groundwork',
#   'modern',
#   'capitalism',
#   'renaissance',
#   'begin',
#   'italy',
#   'spread',
#   'rest',
#   'europe',
#   'bringing',
#   'renew',
#   'interest',
#   'humanism',
#   'science',
#   'exploration',
#   'art',
#   'italian',
#   'culture',
#   'flourish',
#   'produce',
#   'famous',
#   'scholar',
#   'artist',
#   'polymath',
#   'middle',
#   'age',
#   'italian',
#   'explorer',
#   'discover',
#   'new',
#   'route',
#   'far',
#   'east',
#   'new',
#   'world',
#   'helping',
#   'usher',
#   'european',
#   'age',
#   'discovery',
#   'nevertheless',
#   "italy's",
#   'commercial',
#   'political',
#   'power',
#   'significantly',
#   'wane',
#   'opening',
#   'trade',
#   'route',
#   'bypass',
#   'mediterranean',
#   'century',
#   'infighting',
#   'italian',
#   'city-state',
#   'italian',
#   'war',
#   'th',
#   'th',
#   'century',
#   'left',
#   'region',
#   'fragment',
#   'wa',
#   'subsequently',
#   'conquer',
#   'divide',
#   'european',
#   'power',
#   'france',
#   'spain',
#   'austria',
#   'mid-th',
#   'century',
#   'rising',
#   'italian',
#   'nationalism',
#   'call',
#   'independence',
#   'foreign',
#   'control',
#   'led',
#   'period',
#   'revolutionary',
#   'political',
#   'upheaval',
#   'century',
#   'foreign',
#   'domination',
#   'political',
#   'division',
#   'italy',
#   'wa',
#   'almost',
#   'entirely',
#   'unify',
#   'establish',
#   'kingdom',
#   'italy',
#   'great',
#   'power',
#   'late',
#   'th',
#   'century',
#   'early',
#   'th',
#   'century',
#   'italy',
#   'rapidly',
#   'industrialise',
#   'namely',
#   'north',
#   'acquire',
#   'colonial',
#   'empire',
#   'south',
#   'remain',
#   'largely',
#   'impoverish',
#   'exclude',
#   'industrialisation',
#   'fuel',
#   'large',
#   'influential',
#   'diaspora',
#   'despite',
#   'one',
#   'main',
#   'victor',
#   'world',
#   'war',
#   'italy',
#   'enter',
#   'period',
#   'economic',
#   'crisis',
#   'social',
#   'turmoil',
#   'leading',
#   'rise',
#   'fascist',
#   'dictatorship',
#   'participation',
#   'world',
#   'war',
#   'ii',
#   'axis',
#   'side',
#   'end',
#   'military',
#   'defeat',
#   'economic',
#   'destruction',
#   'italian',
#   'civil',
#   'war',
#   'following',
#   'liberation',
#   'italy',
#   'rise',
#   'resistance',
#   'country',
#   'abolish',
#   'monarchy',
#   'establish',
#   'democratic',
#   'republic',
#   'enjoy',
#   'prolong',
#   'economic',
#   'boom',
#   'become',
#   'highly',
#   'develop',
#   'country',
#   'today',
#   'italy',
#   'consider',
#   'one',
#   "world's",
#   'culturally',
#   'economically',
#   'advance',
#   'country',
#   'economy',
#   'ranking',
#   'eighth-largest',
#   'world',
#   'third',
#   'eurozone',
#   'nominal',
#   'gdp',
#   'italy',
#   'ha',
#   'sixth-largest',
#   'worldwide',
#   'national',
#   'wealth',
#   'third-largest',
#   'central',
#   'bank',
#   'gold',
#   'reserve',
#   'high',
#   'life',
#   'expectancy',
#   'country',
#   'play',
#   'prominent',
#   'role',
#   'regional',
#   'global',
#   'economic',
#   'military',
#   'cultural',
#   'diplomatic',
#   'affairs;',
#   'regional',
#   'power',
#   'great',
#   'power',
#   'rank',
#   "world's",
#   'eighth',
#   'most-powerful',
#   'military',
#   'italy',
#   'founding',
#   'leading',
#   'member',
#   'european',
#   'union',
#   'member',
#   'numerous',
#   'international',
#   'institution',
#   'include',
#   'un',
#   'nato',
#   'oecd',
#   'osce',
#   'wto',
#   'g',
#   'g',
#   'union',
#   'mediterranean',
#   'council',
#   'europe',
#   'uniting',
#   'consensus',
#   'schengen',
#   'area',
#   'many',
#   'country',
#   'greatly',
#   'influence',
#   'contribute',
#   'diverse',
#   'fields',
#   'notably',
#   'arts',
#   'music',
#   'literature',
#   'philosophy',
#   'science',
#   'technology',
#   'fashion',
#   'cinema',
#   'cuisine',
#   'sport',
#   'well',
#   'jurisprudence',
#   'banking',
#   'business',
#   'reflection',
#   'cultural',
#   'wealth',
#   'italy',
#   'home',
#   "world's",
#   'large',
#   'number',
#   'world',
#   'heritage',
#   'site',
#   '()',
#   'fifth-most',
#   'visit',
#   'country'],
#  ['brazil',
#   'officially',
#   'federative',
#   'republic',
#   'brazil',
#   'large',
#   'country',
#   'south',
#   'america',
#   'latin',
#   'america',
#   'million',
#   'square',
#   'kilometer',
#   '(',
#   'million',
#   'square',
#   'miles)',
#   'million',
#   'people',
#   'brazil',
#   "world's",
#   'fifth-largest',
#   'country',
#   'area',
#   'fifth',
#   'populous',
#   'capital',
#   'brasília',
#   'populate',
#   'city',
#   'são',
#   'paulo',
#   'federation',
#   'compose',
#   'union',
#   'state',
#   'federal',
#   'district',
#   'municipality',
#   'large',
#   'country',
#   'portuguese',
#   'official',
#   'language',
#   'one',
#   'americas;',
#   'also',
#   'one',
#   'multicultural',
#   'ethnically',
#   'diverse',
#   'nation',
#   'due',
#   'century',
#   'mass',
#   'immigration',
#   'around',
#   'world',
#   'bound',
#   'atlantic',
#   'ocean',
#   'east',
#   'brazil',
#   'ha',
#   'coastline',
#   'kilometer',
#   '(',
#   'mi)',
#   'border',
#   'south',
#   'american',
#   'country',
#   'except',
#   'ecuador',
#   'chile',
#   'cover',
#   "continent's",
#   'land',
#   'area',
#   'amazon',
#   'river',
#   'basin',
#   'include',
#   'vast',
#   'tropical',
#   'forest',
#   'home',
#   'diverse',
#   'wildlife',
#   'variety',
#   'ecological',
#   'system',
#   'extensive',
#   'natural',
#   'resource',
#   'span',
#   'numerous',
#   'protect',
#   'habitat',
#   'unique',
#   'environmental',
#   'heritage',
#   'make',
#   'brazil',
#   'one',
#   'megadiverse',
#   'country',
#   'subject',
#   'significant',
#   'global',
#   'interest',
#   'debate',
#   'regard',
#   'deforestation',
#   'environmental',
#   'protection',
#   'brazil',
#   'wa',
#   'inhabit',
#   'numerous',
#   'tribal',
#   'nation',
#   'prior',
#   'landing',
#   'explorer',
#   'pedro',
#   'álvares',
#   'cabral',
#   'claim',
#   'area',
#   'portuguese',
#   'empire',
#   'brazil',
#   'remain',
#   'portuguese',
#   'colony',
#   'capital',
#   'empire',
#   'wa',
#   'transfer',
#   'lisbon',
#   'rio',
#   'de',
#   'janeiro',
#   'colony',
#   'wa',
#   'elevated',
#   'rank',
#   'kingdom',
#   'upon',
#   'formation',
#   'unite',
#   'kingdom',
#   'portugal',
#   'brazil',
#   'algarves',
#   'independence',
#   'wa',
#   'achieve',
#   'creation',
#   'empire',
#   'brazil',
#   'unitary',
#   'state',
#   'governed',
#   'constitutional',
#   'monarchy',
#   'parliamentary',
#   'system',
#   'ratification',
#   'first',
#   'constitution',
#   'led',
#   'formation',
#   'bicameral',
#   'legislature',
#   'call',
#   'national',
#   'congress',
#   'country',
#   'become',
#   'presidential',
#   'republic',
#   'following',
#   'military',
#   'coup',
#   "d'état",
#   'authoritarian',
#   'military',
#   'junta',
#   'come',
#   'power',
#   'rule',
#   'civilian',
#   'governance',
#   'resume',
#   "brazil's",
#   'current',
#   'constitution',
#   'formulate',
#   'define',
#   'democratic',
#   'federal',
#   'republic',
#   'due',
#   'rich',
#   'culture',
#   'history',
#   'country',
#   'rank',
#   'thirteenth',
#   'world',
#   'number',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'brazil',
#   'consider',
#   'advance',
#   'emerge',
#   'economy',
#   'ha',
#   'ninth',
#   'large',
#   'gdp',
#   'world',
#   'nominal',
#   'eight',
#   'ppp',
#   'measure',
#   'one',
#   "world's",
#   'major',
#   'breadbasket',
#   'large',
#   'producer',
#   'coffee',
#   'last',
#   'years',
#   'classified',
#   'upper-middle',
#   'income',
#   'economy',
#   'world',
#   'bank',
#   'newly',
#   'industrialize',
#   'country',
#   'large',
#   'share',
#   'global',
#   'wealth',
#   'latin',
#   'america',
# ...
#   'large',
#   'city',
#   'madrid;',
#   'major',
#   'urban',
#   'area',
#   'include',
#   'barcelona',
#   'valencia',
#   'seville',
#   'málaga',
#   'bilbao',
#   'modern',
#   'humans',
#   'first',
#   'arrive',
#   'iberian',
#   'peninsula',
#   'around',
#   'years',
#   'ago',
#   'iberian',
#   'culture',
#   'along',
#   'ancient',
#   'phoenician',
#   'greek',
#   'celtic',
#   'carthaginian',
#   'settlement',
#   'develop',
#   'peninsula',
#   'come',
#   'roman',
#   'rule',
#   'around',
#   'bce',
#   'region',
#   'wa',
#   'name',
#   'hispania',
#   'base',
#   'earlier',
#   'phoenician',
#   'name',
#   'spn',
#   'spania',
#   'end',
#   'western',
#   'roman',
#   'empire',
#   'germanic',
#   'tribal',
#   'confederation',
#   'migrate',
#   'central',
#   'europe',
#   'invade',
#   'iberian',
#   'peninsula',
#   'establish',
#   'relatively',
#   'independent',
#   'realm',
#   'western',
#   'province',
#   'include',
#   'suebi',
#   'alans',
#   'vandal',
#   'eventually',
#   'visigoth',
#   'would',
#   'forcibly',
#   'integrate',
#   'remain',
#   'independent',
#   'territory',
#   'peninsula',
#   'include',
#   'byzantine',
#   'province',
#   'kingdom',
#   'toledo',
#   'le',
#   'unify',
#   'politically',
#   'ecclesiastically',
#   'legally',
#   'former',
#   'roman',
#   'province',
#   'successor',
#   'kingdom',
#   'wa',
#   'document',
#   'hispania',
#   'early',
#   'eighth',
#   'century',
#   'visigothic',
#   'kingdom',
#   'fell',
#   'moor',
#   'umayyad',
#   'islamic',
#   'caliphate',
#   'arrive',
#   'rule',
#   'peninsula',
#   'year',
#   'leaving',
#   'handful',
#   'small',
#   'christian',
#   'realm',
#   'north',
#   'last',
#   'seven',
#   'century',
#   'kingdom',
#   'granada',
#   'led',
#   'many',
#   'war',
#   'long',
#   'reconquer',
#   'period',
#   'across',
#   'iberian',
#   'peninsula',
#   'led',
#   'creation',
#   'kingdom',
#   'leon',
#   'kingdom',
#   'castille',
#   'kingdom',
#   'aragon',
#   'kingdom',
#   'navarre',
#   'main',
#   'christian',
#   'kingdom',
#   'face',
#   'invasion',
#   'following',
#   'moorish',
#   'conquest',
#   'european',
#   'begin',
#   'gradual',
#   'process',
#   'retaking',
#   'region',
#   'know',
#   'reconquista',
#   'late',
#   'th',
#   'century',
#   'culminate',
#   'emergence',
#   'spain',
#   'unify',
#   'country',
#   'catholic',
#   'monarch',
#   'early',
#   'modern',
#   'period',
#   'spain',
#   'become',
#   "world's",
#   'first',
#   'global',
#   'empire',
#   'powerful',
#   'country',
#   'world',
#   'leaving',
#   'large',
#   'cultural',
#   'linguistic',
#   'legacy',
#   'include',
#   '+',
#   'million',
#   'hispanophones',
#   'making',
#   'spanish',
#   "world's",
#   'second-most',
#   'speak',
#   'native',
#   'language',
#   'mandarin',
#   'chinese',
#   'golden',
#   'age',
#   'also',
#   'many',
#   'advancement',
#   'arts',
#   'world-famous',
#   'painter',
#   'diego',
#   'velázquez',
#   'famous',
#   'spanish',
#   'literary',
#   'work',
#   'quixote',
#   'wa',
#   'also',
#   'publish',
#   'golden',
#   'age',
#   'spain',
#   'host',
#   "world's",
#   'third-largest',
#   'number',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'spain',
#   'secular',
#   'parliamentary',
#   'democracy',
#   'parliamentary',
#   'monarchy',
#   'king',
#   'felipe',
#   'vi',
#   'head',
#   'state',
#   'major',
#   'develop',
#   'country',
#   'high',
#   'income',
#   'country',
#   "world's",
#   'fourteenth',
#   'large',
#   'economy',
#   'nominal',
#   'gdp',
#   'sixteenth',
#   'large',
#   'purchasing',
#   'power',
#   'parity',
#   'member',
#   'unite',
#   'nation',
#   '(un)',
#   'european',
#   'union',
#   '(eu)',
#   'eurozone',
#   'council',
#   'europe',
#   '(coe)',
#   'organization',
#   'ibero-american',
#   'state',
#   '(oei)',
#   'union',
#   'mediterranean',
#   'north',
#   'atlantic',
#   'treaty',
#   'organization',
#   '(nato)',
#   'organisation',
#   'economic',
#   'co-operation',
#   'development',
#   '(oecd)',
#   'organization',
#   'security',
#   'co-operation',
#   'europe',
#   '(osce)',
#   'schengen',
#   'area',
#   'world',
#   'trade',
#   'organization',
#   '(wto)',
#   'many',
#   'international',
#   'organisation',
#   'official',
#   'member',
#   'spain',
#   'ha',
#   '"permanent',
#   'invitation"',
#   'g',
#   'summit',
#   'participate',
#   'every',
#   'summit',
#   'make',
#   'spain',
#   'de',
#   'facto',
#   'member',
#   'group'],
#  ['australia',
#   'officially',
#   'commonwealth',
#   'australia',
#   'sovereign',
#   'country',
#   'comprise',
#   'mainland',
#   'australian',
#   'continent',
#   'island',
#   'tasmania',
#   'numerous',
#   'smaller',
#   'island',
#   'large',
#   'country',
#   'oceania',
#   "world's",
#   'sixth-largest',
#   'country',
#   'total',
#   'area',
#   'neighbour',
#   'country',
#   'papua',
#   'new',
#   'guinea',
#   'indonesia',
#   'east',
#   'timor',
#   'north;',
#   'solomon',
#   'island',
#   'vanuatu',
#   'north-east;',
#   'new',
#   'zealand',
#   'south-east',
#   'population',
#   'million',
#   'highly',
#   'urbanise',
#   'heavily',
#   'concentrate',
#   'eastern',
#   'seaboard',
#   "australia's",
#   'capital',
#   'canberra',
#   'large',
#   'city',
#   'sydney',
#   "country's",
#   'major',
#   'metropolitan',
#   'area',
#   'melbourne',
#   'brisbane',
#   'perth',
#   'adelaide',
#   'indigenous',
#   'australian',
#   'inhabit',
#   'continent',
#   'years',
#   'prior',
#   'european',
#   'discovery',
#   'arrival',
#   'dutch',
#   'explorer',
#   'early',
#   'th',
#   'century',
#   'name',
#   'new',
#   'holland',
#   "australia's",
#   'eastern',
#   'half',
#   'wa',
#   'claim',
#   'great',
#   'britain',
#   'initially',
#   'settle',
#   'penal',
#   'transportation',
#   'colony',
#   'new',
#   'south',
#   'wales',
#   'january',
#   'date',
#   'become',
#   "australia's",
#   'national',
#   'day',
#   'population',
#   'grow',
#   'steadily',
#   'subsequent',
#   'decade',
#   'time',
#   'gold',
#   'rush',
#   'continent',
#   'explore',
#   'additional',
#   'five',
#   'self-governing',
#   'crown',
#   'colony',
#   'establish',
#   'january',
#   'six',
#   'colony',
#   'federate',
#   'form',
#   'commonwealth',
#   'australia',
#   'australia',
#   'ha',
#   'since',
#   'maintain',
#   'stable',
#   'liberal',
#   'democratic',
#   'political',
#   'system',
#   'function',
#   'federal',
#   'parliamentary',
#   'constitutional',
#   'monarchy',
#   'comprise',
#   'six',
#   'state',
#   'ten',
#   'territory',
#   'old',
#   'flat',
#   'dry',
#   'inhabit',
#   'continent',
#   'least',
#   'fertile',
#   'soil',
#   'australia',
#   'ha',
#   'landmass',
#   'square',
#   'kilometre',
#   '(',
#   'sq',
#   'mi)',
#   'megadiverse',
#   'country',
#   'size',
#   'give',
#   'wide',
#   'variety',
#   'landscape',
#   'deserts',
#   'centre',
#   'tropical',
#   'rainforest',
#   'north-east',
#   'mountain',
#   'range',
#   'south-east',
#   'population',
#   'density',
#   'inhabitant',
#   'per',
#   'square',
#   'kilometre',
#   'remains',
#   'among',
#   'lowest',
#   'world',
#   'australia',
#   'generate',
#   'income',
#   'various',
#   'source',
#   'include',
#   'mining-related',
#   'export',
#   'telecommunication',
#   'banking',
#   'manufacturing',
#   'australia',
#   'highly',
#   'develop',
#   'country',
#   "world's",
#   'th-largest',
#   'economy',
#   'ha',
#   'high-income',
#   'economy',
#   "world's",
#   'tenth-highest',
#   'per',
#   'caput',
#   'income',
#   'regional',
#   'power',
#   'ha',
#   "world's",
#   'th-highest',
#   'military',
#   'expenditure',
#   'australia',
#   'ha',
#   "world's",
#   'eighth-largest',
#   'immigrant',
#   'population',
#   'immigrant',
#   'accounting',
#   'population',
#   'third-highest',
#   'human',
#   'development',
#   'index',
#   'eighth-highest',
#   'rank',
#   'democracy',
#   'globally',
#   'country',
#   'rank',
#   'highly',
#   'quality',
#   'life',
#   'health',
#   'education',
#   'economic',
#   'freedom',
#   'civil',
#   'liberty',
#   'political',
#   'right',
#   'major',
#   'city',
#   'fare',
#   'well',
#   'global',
#   'comparative',
#   'livability',
#   'survey',
#   'australia',
#   'member',
#   'unite',
#   'nation',
#   'g',
#   'commonwealth',
#   'nation',
#   'anzus',
#   'organisation',
#   'economic',
#   'co-operation',
#   'development',
#   '(oecd)',
#   'world',
#   'trade',
#   'organization',
#   'asia-pacific',
#   'economic',
#   'cooperation',
#   'pacific',
#   'island',
#   'forum',
#   'asean',
#   'plus',
#   'six',
#   'mechanism'],
#  ['indonesia',
#   'officially',
#   'republic',
#   'indonesia',
#   '(indonesian:',
#   'republik',
#   'indonesia',
#   '[reˈpublik',
#   'ɪndoˈnesia])[a]',
#   'country',
#   'southeast',
#   'asia',
#   'indian',
#   'pacific',
#   'ocean',
#   "world's",
#   'large',
#   'island',
#   'country',
#   'seventeen',
#   'thousand',
#   'island',
#   'square',
#   'kilometre',
#   '(',
#   'square',
#   'miles)',
#   'th',
#   'large',
#   'land',
#   'area',
#   'th',
#   'large',
#   'combine',
#   'sea',
#   'land',
#   'area',
#   'million',
#   'people',
#   "world's",
#   'th',
#   'populous',
#   'country',
#   'well',
#   'populous',
#   'muslim-majority',
#   'country',
#   'java',
#   "world's",
#   'populous',
#   'island',
#   'home',
#   'half',
#   "country's",
#   'population',
#   'sovereign',
#   'state',
#   'presidential',
#   'constitutional',
#   'republic',
#   'elect',
#   'parliament',
#   'ha',
#   'province',
#   'five',
#   'special',
#   'status',
#   'jakarta',
#   "country's",
#   'capital',
#   'second',
#   'populous',
#   'urban',
#   'area',
#   'world',
#   'country',
#   'share',
#   'land',
#   'border',
#   'papua',
#   'new',
#   'guinea',
#   'east',
#   'timor',
#   'eastern',
#   'part',
#   'malaysia',
#   'neighbour',
#   'country',
#   'include',
#   'singapore',
#   'vietnam',
#   'philippines',
#   'australia',
#   'palau',
#   "india's",
#   'andaman',
#   'nicobar',
#   'island',
#   'despite',
#   'large',
#   'population',
#   'densely',
#   'populate',
#   'region',
#   'indonesia',
#   'ha',
#   'vast',
#   'area',
#   'wilderness',
#   'support',
#   'high',
#   'level',
#   'biodiversity',
#   'country',
#   'ha',
#   'abundant',
#   'natural',
#   'resource',
#   'like',
#   'oil',
#   'natural',
#   'gas',
#   'tin',
#   'copper',
#   'gold',
#   'agriculture',
#   'mainly',
#   'produce',
#   'rice',
#   'palm',
#   'oil',
#   'tea',
#   'coffee',
#   'cacao',
#   'medicinal',
#   'plant',
#   'spice',
#   'rubber',
#   "indonesia's",
#   'major',
#   'trading',
#   'partner',
#   'china',
#   'unite',
#   'state',
#   'japan',
#   'singapore',
#   'india',
#   'history',
#   'indonesian',
#   'archipelago',
#   'ha',
#   'influence',
#   'foreign',
#   'power',
#   'draw',
#   'natural',
#   'resource',
#   'ha',
#   'important',
#   'region',
#   'trade',
#   'since',
#   'least',
#   'th',
#   'century',
#   'srivijaya',
#   'later',
#   'majapahit',
#   'trade',
#   'entity',
#   'mainland',
#   'china',
#   'indian',
#   'subcontinent',
#   'local',
#   'ruler',
#   'gradually',
#   'absorb',
#   'foreign',
#   'cultural',
#   'religious',
#   'political',
#   'model',
#   'early',
#   'century',
#   'hindu',
#   'buddhist',
#   'kingdom',
#   'flourish',
#   'muslim',
#   'trader',
#   'sufi',
#   'scholar',
#   'bring',
#   'islam',
#   'european',
#   'power',
#   'bring',
#   'christianity',
#   'fight',
#   'one',
#   'another',
#   'monopolise',
#   'trade',
#   'spice',
#   'island',
#   'maluku',
#   'age',
#   'discovery',
#   'although',
#   'sometimes',
#   'interrupt',
#   'portuguese',
#   'french',
#   'british',
#   'dutch',
#   'foremost',
#   'european',
#   'power',
#   'much',
#   '-year',
#   'presence',
#   'archipelago',
#   'early',
#   'th',
#   'century',
#   'concept',
#   '"indonesia"',
#   'nation',
#   'state',
#   'emerge',
#   'independence',
#   'movement',
#   'begin',
#   'take',
#   'shape',
#   'decolonisation',
#   'asia',
#   'world',
#   'war',
#   'ii',
#   'indonesia',
#   'achieve',
#   'independence',
#   'following',
#   'arm',
#   'diplomatic',
#   'conflict',
#   'netherlands',
#   'indonesia',
#   'consist',
#   'hundred',
#   'distinct',
#   'native',
#   'ethnic',
#   'linguistic',
#   'group',
#   'largest—and',
#   'politically',
#   'dominant—ethnic',
#   'group',
#   'javanese',
#   'share',
#   'identity',
#   'ha',
#   'develop',
#   'define',
#   'national',
#   'language',
#   'ethnic',
#   'diversity',
#   'religious',
#   'pluralism',
#   'within',
#   'muslim-majority',
#   'population',
#   'history',
#   'colonialism',
#   'rebellion',
#   "indonesia's",
#   'national',
#   'motto',
#   '"bhinneka',
#   'tunggal',
#   'ika"',
#   '("unity',
#   'diversity"',
#   'literally',
#   '"many',
#   'yet',
#   'one")',
#   'articulate',
#   'diversity',
#   'shape',
#   'country',
#   "indonesia's",
#   'economy',
#   "world's",
#   'th',
#   'large',
#   'nominal',
#   'gdp',
#   'th',
#   'large',
#   'gdp',
#   'ppp',
#   'indonesia',
#   'member',
#   'several',
#   'multilateral',
#   'organisation',
#   'include',
#   'un[b]',
#   'wto',
#   'imf',
#   'g',
#   'also',
#   'founding',
#   'member',
#   'non-aligned',
#   'movement',
#   'association',
#   'southeast',
#   'asian',
#   'nation',
#   'asia-pacific',
#   'economic',
#   'cooperation',
#   'east',
#   'asia',
#   'summit',
#   'asian',
#   'infrastructure',
#   'investment',
#   'bank',
#   'organisation',
#   'islamic',
#   'cooperation'],
#  ['mexico',
#   'officially',
#   'unite',
#   'mexican',
#   'state',
#   '(spanish:',
#   'estados',
#   'unidos',
#   'mexicano',
#   'country',
#   'southern',
#   'portion',
#   'north',
#   'america',
#   'border',
#   'north',
#   'unite',
#   'states;',
#   'south',
#   'west',
#   'pacific',
#   'ocean;',
#   'southeast',
#   'guatemala',
#   'belize',
#   'caribbean',
#   'sea;',
#   'east',
#   'gulf',
#   'mexico',
#   'covering',
#   'almost',
#   'square',
#   'kilometer',
#   '(',
#   'sq',
#   'mi)',
#   'nation',
#   'fifth',
#   'large',
#   'country',
#   'america',
#   'total',
#   'area',
#   'th',
#   'large',
#   'independent',
#   'state',
#   'world',
#   'estimate',
#   'population',
#   'million',
#   'people',
#   'country',
#   'tenth',
#   'populous',
#   'state',
#   'populous',
#   'spanish-speaking',
#   'state',
#   'world',
#   'second',
#   'populous',
#   'nation',
#   'latin',
#   'america',
#   'brazil',
#   'mexico',
#   'federation',
#   'comprise',
#   'state',
#   'mexico',
#   'city',
#   'special',
#   'federal',
#   'entity',
#   'also',
#   'capital',
#   'city',
#   'populous',
#   'city',
#   'metropolis',
#   'state',
#   'include',
#   'guadalajara',
#   'monterrey',
#   'puebla',
#   'toluca',
#   'tijuana',
#   'león',
#   'pre-columbian',
#   'mexico',
#   'date',
#   'bc',
#   'identify',
#   'one',
#   'five',
#   'cradle',
#   'civilization',
#   'wa',
#   'home',
#   'many',
#   'advance',
#   'mesoamerican',
#   'civilization',
#   'olmec',
#   'toltec',
#   'teotihuacan',
#   'zapotec',
#   'maya',
#   'aztec',
#   'first',
#   'contact',
#   'european',
#   'spanish',
#   'empire',
#   'conquer',
#   'colonize',
#   'territory',
#   'politically',
#   'powerful',
#   'base',
#   'mexico-tenochtitlan',
#   '(part',
#   'mexico',
#   'city)',
#   'wa',
#   'administer',
#   'viceroyalty',
#   'new',
#   'spain',
#   'three',
#   'century',
#   'later',
#   'territory',
#   'become',
#   'nation',
#   'state',
#   'following',
#   'recognition',
#   'mexican',
#   'war',
#   'independence',
#   'post-independence',
#   'period',
#   'wa',
#   'tumultuous',
#   'characterize',
#   'economic',
#   'inequality',
#   'many',
#   'contrast',
#   'political',
#   'change',
#   'mexican–american',
#   'war',
#   '(–)',
#   'led',
#   'territorial',
#   'cession',
#   'extant',
#   'northern',
#   'territory',
#   'unite',
#   'state',
#   'pastry',
#   'war',
#   'franco-mexican',
#   'war',
#   'civil',
#   'war',
#   'two',
#   'empire',
#   'porfiriato',
#   'occur',
#   'th',
#   'century',
#   'porfiriato',
#   'end',
#   'mexican',
#   'revolution',
#   'culminate',
#   'promulgation',
#   'constitution',
#   'emergence',
#   'authoritarian',
#   'one-party',
#   'state',
#   'widely',
#   'describe',
#   '"perfect',
#   'dictatorship"',
#   'rule',
#   'much',
#   'th',
#   'century',
#   'electoral',
#   'reform',
#   'opposition',
#   'victory',
#   'led',
#   "mexico's",
#   'democratic',
#   'transition',
#   'mexico',
#   'ha',
#   'th',
#   'large',
#   'nominal',
#   'gdp',
#   'th',
#   'large',
#   'purchasing',
#   'power',
#   'parity',
#   'mexican',
#   'economy',
#   'strongly',
#   'link',
#   'north',
#   'american',
#   'free',
#   'trade',
#   'agreement',
#   '(nafta)',
#   'partner',
#   'especially',
#   'unite',
#   'state',
#   'mexico',
#   'become',
#   'first',
#   'latin',
#   'american',
#   'member',
#   'organisation',
#   'economic',
#   'co-operation',
#   'development',
#   '(oecd)',
#   'classified',
#   'upper-middle',
#   'income',
#   'country',
#   'world',
#   'bank',
#   'newly',
#   'industrialize',
#   'country',
#   'several',
#   'analyst',
#   'country',
#   'consider',
#   'regional',
#   'power',
#   'middle',
#   'power',
#   'often',
#   'identify',
#   'emerge',
#   'global',
#   'power',
#   'due',
#   'rich',
#   'culture',
#   'history',
#   'mexico',
#   'rank',
#   'first',
#   'america',
#   'seventh',
#   'world',
#   'number',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'mexico',
#   'ecologically',
#   'megadiverse',
#   'country',
#   'ranking',
#   'fourth',
#   'world',
#   'biodiversity',
#   'mexico',
#   'receive',
#   'huge',
#   'number',
#   'tourist',
#   'every',
#   'year:',
#   'wa',
#   'sixth',
#   'most-visited',
#   'country',
#   'world',
#   'million',
#   'international',
#   'arrival',
#   'mexico',
#   'member',
#   'unite',
#   'nation',
#   '(un)',
#   'world',
#   'trade',
#   'organization',
#   '(wto)',
#   'g+',
#   'g',
#   'uniting',
#   'consensus',
#   'group',
#   'un',
#   'pacific',
#   'alliance',
#   'trade',
#   'bloc']]

# %% [markdown]
# # Set Based similarity: Set representation + Jaccard Distance and Dice Similarity

# %%
from nltk.metrics import jaccard_distance

def cal_jd(base_set, set_list):
    result = {}
    set_a = set(base_set)
    for i, x in enumerate(set_list):
        set_b = set(set_list[i])
        result[i] = 1 - jaccard_distance(set_a, set_b)
    
    return result

# %%
result = cal_jd(pp_text_data[0], pp_text_data)
sorted(result.items(), key=lambda x:x[1], reverse = True)
# Out:
# [(0, 1.0),
#  (8, 0.17579908675799083),
#  (6, 0.17298578199052128),
#  (9, 0.17004048582995956),
#  (12, 0.14592274678111583),
#  (13, 0.14392059553349879),
#  (10, 0.1410891089108911),
#  (14, 0.14087759815242495),
#  (5, 0.13970588235294112),
#  (3, 0.13701923076923073),
#  (15, 0.13603818615751795),
#  (7, 0.13559322033898302),
#  (1, 0.13406593406593403),
#  (11, 0.12740384615384615),
#  (2, 0.12121212121212122),
#  (4, 0.1071428571428571)]

# %%
def dice_similarity(set_a, set_b):
    num_intersection = len(set.intersection(set_a, set_b))
    sum_nums = len(set_a) + len(set_b)
    try:
        return 2 * num_intersection / sum_nums
    except ZeroDivisionError:
        return 1.0
    
def cal_ds(base_set, set_list):
    result = {}
    set_a = set(base_set)
    for i, x in enumerate(set_list):
        set_b = set(set_list[i])
        result[i] = dice_similarity(set_a, set_b)
    
    return result

# %%
result = cal_ds(pp_text_data[0], pp_text_data)
sorted(result.items(), key=lambda x:x[1], reverse = True)
# Out:
# [(0, 1.0),
#  (8, 0.29902912621359223),
#  (6, 0.29494949494949496),
#  (9, 0.2906574394463668),
#  (12, 0.2546816479400749),
#  (13, 0.25162689804772237),
#  (10, 0.2472885032537961),
#  (14, 0.24696356275303644),
#  (5, 0.24516129032258063),
#  (3, 0.24101479915433405),
#  (15, 0.23949579831932774),
#  (7, 0.23880597014925373),
#  (1, 0.2364341085271318),
#  (11, 0.2260127931769723),
#  (2, 0.21621621621621623),
#  (4, 0.1935483870967742)]

# %% [markdown]
# # Vector Based similarity: tfidf + cosine similarity

# %%
def tfidf_vectorizer(docs):
    def tf(word2id, doc):
        term_counts = np.zeros(len(word2id))
        for term in word2id.keys():
            term_counts[word2id[term]] = doc.count(term)
        tf_values = list(map(lambda x: x/sum(term_counts), term_counts))
        return tf_values
    
    def idf(word2id, docs):
        idf = np.zeros(len(word2id))
        for term in word2id.keys():
            idf[word2id[term]] = np.log(len(docs) / sum([bool(term in doc) for doc in docs]))
        return idf
    
    word2id = {}
    for doc in docs:
        for w in doc:
            if w not in word2id:
                word2id[w] = len(word2id)
                
    return [[_tf*_idf for _tf, _idf in zip(tf(word2id, doc), idf(word2id, docs))] for doc in docs], word2id

# %%
def cosine_similarity(list_a, list_b):
    inner_prod = np.array(list_a).dot(np.array(list_b))
    norm_a = np.linalg.norm(list_a)
    norm_b = np.linalg.norm(list_b)
    try:
        return inner_prod / (norm_a * norm_b)
    except ZeroDivisionError:
        return 1.0

# %%
def cal_cosine(vector, vector_list):
    result = {}
    for i, x in enumerate(vector_list):
        result[i] = cosine_similarity(vector, vector_list[i])
    
    return result

# %%
tfidf_vector, word2id = tfidf_vectorizer(pp_text_data)

# %%
word2id.items()
# Out:
# dict_items([('japan', 0), ('island', 1), ('country', 2), ('east', 3), ('asia', 4), ('locate', 5), ('pacific', 6), ('ocean', 7), ('lie', 8), ('eastern', 9), ('coast', 10), ('asian', 11), ('continent', 12), ('stretch', 13), ('sea', 14), ('okhotsk', 15), ('north', 16), ('china', 17), ('philippine', 18), ('south', 19), ('kanji', 20), ('make', 21), ("japan's", 22), ('name', 23), ('mean', 24), ("'sun", 25), ("origin'", 26), ('often', 27), ('call', 28), ('"land', 29), ('rising', 30), ('sun"', 31), ('stratovolcanic', 32), ('archipelago', 33), ('consist', 34), ('four', 35), ('large', 36), ('honshu', 37), ('hokkaido', 38), ('kyushu', 39), ('shikoku', 40), ('ninety-seven', 41), ('percent', 42), ('land', 43), ('area', 44), ('refer', 45), ('home', 46), ('divide', 47), ('prefecture', 48), ('eight', 49), ('region', 50), ('northernmost', 51), ('okinawa', 52), ('southernmost', 53), ('one', 54), ('nd', 55), ('populous', 56), ('population', 57), ('million', 58), ("world's", 59), ('eleventh', 60), ('ethnic', 61), ('japanese', 62), ('people', 63), ('live', 64), ('city', 65), ('countryside', 66), ('tokyo', 67), ('capital', 68), ('greater', 69), ('metropolitan', 70), ('world', 71), ('archaeological', 72), ('research', 73), ('indicate', 74), ('wa', 75), ('inhabit', 76), ('early', 77), ('upper', 78), ('paleolithic', 79), ('period', 80), ('first', 81), ('write', 82), ('mention', 83), ('chinese', 84), ('history', 85), ('text', 86), ('st', 87), ('century', 88), ('ad', 89), ('influence', 90), ('mainly', 91), ('follow', 92), ('isolation', 93), ('particularly', 94), ('western', 95), ('europe', 96), ('ha', 97), ('characterize', 98), ('th', 99), ('rule', 100), ('successive', 101), ('feudal', 102), ('military', 103), ('shōguns', 104), ('emperor', 105), ('enter', 106), ('long', 107), ('end', 108), ('unite', 109), ('state', 110), ('fleet', 111), ('pressure', 112), ('open', 113), ('west', 114), ('nearly', 115), ('two', 116), ('decade', 117), ('internal', 118), ('conflict', 119), ('insurrection', 120), ('imperial', 121), ('court', 122), ('regain', 123), ('political', 124), ('power', 125), ('help', 126), ('several', 127), ('clan', 128), ('chōshū', 129), ('satsuma', 130), ('–', 131), ('empire', 132), ('establish', 133), ('late', 134), ('victory', 135), ('sino-japanese', 136), ('war', 137), ('russo-japanese', 138), ('allow', 139), ('expand', 140), ('increase', 141), ('militarism', 142), ('second', 143), ('part', 144), ('ii', 145), ('come', 146), ('following', 147), ('surrender', 148), ('since', 149), ('adopt', 150), ('revise', 151), ('constitution', 152), ('may', 153), ('occupation', 154), ('led', 155), ('scap', 156), ('sovereign', 157), ('maintain', 158), ('unitary', 159), ('parliamentary', 160), ('constitutional', 161), ('monarchy', 162), ('elect', 163), ('legislature', 164), ('national', 165), ('diet', 166), ('member', 167), ('asean', 168), ('plus', 169), ('mechanism', 170), ('un', 171), ('oecd', 172), ('g', 173), ('consider', 174), ('great', 175), ('economy', 176), ('third-largest', 177), ('nominal', 178), ('gdp', 179), ('fourth-largest', 180), ('purchasing', 181), ('parity', 182), ('also', 183), ('exporter', 184), ('importer', 185), ('benefit', 186), ('highly', 187), ('skilled', 188), ('educate', 189), ('workforce;', 190), ('among', 191), ('proportion', 192), ('citizen', 193), ('holding', 194), ('tertiary', 195), ('education', 196), ('degree', 197), ('although', 198), ('officially', 199), ('renounce', 200), ('right', 201), ('declare', 202), ('modern', 203), ('eighth-largest', 204), ('budget', 205), ('use', 206), ('self-defense', 207), ('peacekeeping', 208), ('roles;', 209), ('rank', 210), ('fourth', 211), ('most-powerful', 212), ('develop', 213), ('high', 214), ('standard', 215), ('living', 216), ('human', 217), ('development', 218), ('index', 219), ('enjoy', 220), ('life', 221), ('expectancy', 222), ('third', 223), ('lowest', 224), ('infant', 225), ('mortality', 226), ('rate', 227), ('experience', 228), ('issue', 229), ('due', 230), ('aging', 231), ('low', 232) ...

# %%
res = cal_cosine(tfidf_vector[0], tfidf_vector)
sorted(res.items(), key=lambda x:x[1], reverse = True)
# Out:
# [(0, 1.0),
#  (5, 0.089213868005443),
#  (3, 0.07494324927746153),
#  (14, 0.06794378321355647),
#  (9, 0.05446867547327852),
#  (8, 0.05061679443369346),
#  (13, 0.05035814117836253),
#  (1, 0.04945156965230686),
#  (7, 0.04340970910393382),
#  (6, 0.04329186935344453),
#  (12, 0.038469390607195876),
#  (2, 0.0355002685981015),
#  (10, 0.03479541972998953),
#  (11, 0.03392463518350004),
#  (15, 0.029516361108928312),
#  (4, 0.02200165046387345)]
